# %% [markdown]
# ## Ομάδα
#
# Στοιχεία Μέλους 1: Βαρβάρα - Κωνσταντίνα Μαγγελάκη (03119180)
#
# Στοιχεία Μέλους 2: Γεωργία Αργυρού (03119046)

# %% [markdown]
# # Τεχνητή Νοημοσύνη: Εργαστηριακή Άσκηση 2
# ---
#
# Ο στόχος της εργασίας είναι η κατασκευή ενός συστήματος προτάσεων (Recommendation System) για ταινίες. Οι προτάσεις αυτές θα πηγάζουν τόσο από τα χαρακτηριστικά της ταινίας όσο και από ορισμένες αξιολογήσεις του κάθε χρήστη.
#
# Στα δεδομένα της άσκησης περιλαμβάνονται ένα αρχείο με το όνομα movies_metadata.csv το όποιο περιέχει τα χαρακτηριστικά κάθε ταινίας όπως θέμα, σκηνοθέτης ηθοποιοί, λέξεις κλειδιά κ.α. από το imdb καθώς και τα αρχεία ratings.csv τα όποια περιέχουν πραγματικές αξιολογήσεις χρηστών, χωρισμένες σε train και σε test.

# %% [markdown]
# # Εκφώνηση
# Στην παρούσα εργασία σας ζητείται να μελετήσετε και να υλοποιήσετε τα παρακάτω:<br>
#
# ### Μέρος 1
# Στο μέρος 1 και 2 θα εργαστείτε μόνο με το αρχείο movies_metadata.csv, ενώ στο μέρος τρία θα δουλέψετε και με τα αρχεία των αξιολογήσεων.
# #### Ερώτημα 1α
#
# Αρχικά θα πρέπει, αφού μελετήσετε τη δομή και τα χαρακτηριστικά του movies_metadata.csv, να κατασκευάσετε μια βάση γνώσης για την Prolog η όποια ουσιαστικά θα αποτελεί τον κόσμο με τον όποιο θα εργαστείτε στην συνέχεια. Τα κατηγορήματα που θα δημιουργηθούν θα σας βοηθήσουν και στην κατασκευή του recommender και θα είναι της μορφής:
#
# ```
# director(Movie, Director).
# genre(Movie, Genre).
# ```
# #### Ερώτημα 1β
#
# Αφού δημιουργήσετε τον κόσμο του προβλήματος, στη συνέχεια καλείστε να δημιουργήσετε, σε Prolog, απλούς κανόνες οι οποίοι θα βρίσκουν όλες τις ταινίες με:
# 1.	Κοινό θέμα (κάποιες λέξεις σχετικά με το genre κοινές)
# 2.	Αρκετά κοινό θέμα (κάποιες λιγότερες λέξεις σχετικά με το genre κοινές π.χ. 3)
# 3.	Σχετικά κοινό θέμα (λίγες λέξεις σχετικές με το genre κοινές π.χ. 1)
# 4.	Κοινός σκηνοθέτης
# 5.	Ακριβώς ίδια πλοκή (κάποιες λέξεις κλειδιά της πλοκής κοινές)
# 6.	Σχετικά ίδια πλοκή (κάποιες λιγότερες λέξεις κλειδιά κοινές)
# 7.	Ίδιους τους βασικούς ηθοποιούς (και τους 3)
# 8.	Αρκετά ίδιους βασικούς ηθοποιούς (ορισμένους βασικούς ηθοποιούς κοινούς π.χ. 2)
# 9.	Σχετικά ίδιους ηθοποιούς (π.χ. 1 από τους 3)
# 10.	Ίδια γλώσσα
# 11.	Είναι έγχρωμες ή ασπρόμαυρες
# 12. Κοινό studio παραγωγής
# 13. Κοινή χώρα παραγωγής
# 14. Ίδια δεκαετία
#
# Αξίζει να σημειωθεί ότι στα παραπάνω μπορείτε να προσθέσετε περισσότερα ερωτήματα ή να αλλάξετε την κλιμακωσιμότητα των queries (πέρα από το ίδιο, αρκετά ίδιο, σχετικά ίδιο) που θα κατασκευάσετε(π.χ. μια κλίμακα από 1 στα 5 όπου αυτό είναι δυνατόν), μιας και αυτά στην συνέχεια θα χρησιμοποιηθούν για την λειτουργία του recommender. Έτσι μπορείτε να προσθέσετε queries με τα όποια μπορεί να παράγονται καλύτερες συστάσεις  (το αρχείο movie_metadata.csv περιέχει πολλές πληροφορίες ακόμα για κάθε ταινία όπως έτος κυκλοφορίας, βαθμολογία στο imdb, facebοok_likes κ.α.). Το συγκεκριμένο μέρος εργασίας είναι προπαρασκευαστικό οπότε όσο καλύτερα και πλουσιότερα τα ερωτήματα που θα φτιάξετε σε αυτό το μέρος τόσο καλύτερη θα είναι η απόδοσή των συστημάτων συστάσεων των επόμενων ερωτημάτων.
#
# Περισσότερες πληροφορίες για το dataset μπορείτε να διαβάσετε σε αυτό το [Link](https://www.kaggle.com/georgefila/movies-metadata).
# ### Μέρος 2: Recommendation System
# Στο σημείο αυτό καλείστε με βάση αυτά που κάνατε στο μέρος 1 να κατασκευάσετε queries τα όποια θα σας επιστρέφουν παρόμοιες (σε χαρακτηριστικά) ταινίες. Τα ερωτήματα αυτά θα είναι κλιμακούμενα, δηλαδή θα υπάρχουν ερωτήματα που επιστρέφουν αρκετά κοινές ταινίες αλλά και που επιστρέφουν λιγότερο και λιγότερο κοινές (σε μια κλίμακα π.χ. από 1 σε 5). Για παράδειγμα:
#
# ```
# find_simmilar_movies_5("Pirates Of The Caribbean", M).
# M = "Pirates Of The Caribbean: On Stranger Tides"
# M = "The Chronicles Of Narnia"
# M = "Prince Of Persia: The Sands Of Time"
# ...
# ```
# Για παράδειγμα, το παραπάνω ερώτημα θα επιστρέφει αρκετά κοινές σε περιεχόμενο ταινίες με την ταινια "Pirates Of The Caribbean". Θα υπάρχουν και αντίστοιχα ερωτήματα που θα βρίσκουν λιγότερο όμοιες ταινίες. Ο δείκτης ομοιότητας των ταινιών είναι αυθαίρετος και μπορείτε να τον ορίσετε εσείς όπως θέλετε, αρκεί να υπάρχει κάποια λογική σύνδεση με τα δεδομένα που περιέχονται στο αρχείο movies_metadata.csv.
#
# Συνεπώς η συνάρτηση που θα κάνει τις προτάσεις (recommendation) με είσοδο μια ταινία πρέπει να επιστρέφει-εκτυπώνει μια λίστα με τις προτεινόμενες ταινίες κατά φθίνουσα σειρά ομοιότητας.
#
#
# ###3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις - Αξιολογήσεις του χρήστη
#
#
# Σε αυτό το σημείο θα εργαστείτε με τα αρχεία ratings τα όποια περιέχουν αξιολογήσεις (από 1 μέχρι 5) για τις παραπάνω ταινίες. Το προηγούμενο σύστημα συστάσεων προτείνει στον χρήστη ταινίες αποκλειστικά με βάση την ομοιότητά τους. Σε αυτό το σημείο θα γίνει μια αναβάθμιση του συστήματος έτσι ώστε να παράγονται καλύτερες  συστάσεις οι όποιες θα λαμβάνουν υπόψιν και τις προτιμήσεις του χρήστη, οι όποιες θα εξάγονται από τις αξιολογήσεις που έχει κάνει μέχρι στιγμής.
#
# Η εκπαίδευση του recommender θα γίνεται ως εξής:
#
# Για κάθε ταινία θα υπάρχει ένα score το όποιο αρχικά θε είναι ίσο με 0 και θα διαμορφώνεται από τις αξιολογήσεις κάθε user. Έτσι για έναν χρήστη με βάση τις αξιολογήσεις που υπάρχουν στο αρχείο train_ratings θα πρέπει:
#
# 1.	Για κάθε ταινία που έχει βαθμολογήσει να βρίσκονται οι κοινές ταινίες ανά κλίμακα και στο μέχρι τώρα σκορ κάθε παρόμοιας ταινίας θα προστίθεται ένα βάρος το όποιο θα μπορούσε να είναι το ποσοστό ομοιότητας της ταινίας (δηλαδή ένα βάρος για κάθε κλίμακα, αν δύο ταινίες μοιάζουν ενισχύουμε το βάρος που προσθέτουμε από το να μοιάζουν λιγότερο) επί τον βαθμό που έχει βάλει ο χρήστης για την αρχική ταινία (διαφορετικό είναι ο χρήστης να έχει βάλει 5/5 ή 1/5 σε μια ταινία από 3/5).
#
# 2. Στη συνέχεια, ανάλογα με το σκορ που έχει σχηματιστεί για κάθε ταινία, θα επιλέγεται αν αυτή θα μπορούσε να είναι προτεινόμενη για τον χρήστη ή όχι και θα μετράμε το πόσο καλά τα πήγε το σύστήμά μας με βάση ορισμένες μετρικές.
#
# Η λογική πίσω από την παραπάνω διαδικασία είναι ότι παρόμοιες ταινίες θα έχουν ανάλογο βαθμό. Για παράδειγμα αν ένας χρήστης έχει αξιολογήσει αρκετές  ταινίες οι όποιες είναι sci-fiction με 5/5 τότε μια ταίνια sci-fiction την όποια δεν έχει δεί λογικά θα του αρέσει και θα έπρεπε να την προτείνουμε.
#
# Μετά την εκπαίδευση του συστήματος σας καλείστε να δοκιμάσετε τον recommender που κατασκευάσατε στην πράξη. Για τον σκοπό αυτό θα φορτώσετε το αρχείο test_ratings.csv όπου περιέχονται οι αξιολογήσεις του ίδιου χρήστη για άλλες ταινίες. Το σύστημά σας πρέπει να προβλέπει αν μια ταινία θα πρέπει να προταθεί στον χρήστη. Μια ταίνια θεωρούμε οτι προτείνεται στον  χρήστη, αν έχει βαθμό μεγαλύτερο του 3 στο test_ratings. Συνεπώς για την επίβλεψη του συστήματός σας θα πρέπει για κάθε μια από τις ταινίες του αρχείου test_ratings.csv να προβλέψετε εάν θα αρέσει στο χρήστη ή όχι ώστε να την προτείνετε.
#
# ΠΡΟΣΟΧΗ! Η "βαθμολογία" που θα υπολογίσετε για κάθε ταινία κατά το training δεν είναι απαραίτητα πρόβλεψη της βαθμολογίας που θα έβαζε ο χρήστης.
#
# Στην συνέχεια, σε συνδιασμό με τις πραγματικές απαντήσεις του χρήστη θα αξιολογήσετε το σύστημά σας χρησιμοποιόντας τις μετρικές: precision, recall, f1 οι οποίες είναι οι πλέον γνωστές μετρικές και ευρέως χρησιμοποιούμενες τεχνικές για την επίβλεψη-μέτρηση απόδοσης ανάλογων συστημάτων.
#
# 1. Precision: Δείχνει πόσο ακριβές είναι το σύστημα. Υπολογίζει πόσα από τα στιγμιότυπα τα όποια προβλέψαμε ότι ανήκουν σε μια κλάση όντως ανήκουν σε αυτή. Η μετρική αυτή μας δίνει μια εικόνα σχετικά με τον αριθμό των ταινίων που προβλέψαμε ως προτεινόμενες ενώ δεν θα έπρεπε.
#
# 2. Recall: Υπολογίζει πόσα από τα στιγμιότυπα που ανήκουν σε μια κλάση (π.χ. προτεινόμενες ταινίες) προβλέφθηκαν σωστά.
#
# 3. F1: Είναι ένας μέσος μεταξύ των παραπάνω δυο μετρικών, έτσι ώστε να διατηρείται μια ισορροπία μεταξύ τους. Υπολογίζεται από την παρακάτω σχέση:
#
# $$F_1=2\frac{Precision\times{Recall}}{Precision+Recall}$$
#
# Οι παραπάνω συναρτήσεις παρέχονται από την βιβλιοθήκη scikit-learn.
#
# Τέλος για την καλύτερη επίβλεψη του συστήματος σας μπορείτε να εκπαιδεύσετε  τον recommender σας με ένα υποσύνολο ταινίων από ελάχιστες, λίγες μέχρι και πολλές (π.χ. 3, 5, 10, 50, ...) για να μελετήσετε κατά πόσο σας βοηθούν οι επιπλέον αξιολογήσεις κάθε φορά (δηλαδή κατά πόσο βελτιώνονται οι παραπάνω μετρικές στο test set).
#
# Έτσι π.χ. μπορείτε να εντοπίσετε περιπτώσεις όπως για παράδειγμα ότι με έναν recommender μπορεί να μην επιτυγχάνετε πολύ υψηλό σκορ όσο με άλλους, αλλά το βέλτιστο σκόρ σας επιτυγχάνεται πολύ γρηγόρα π.χ. με μόνο 10 ταινίες αντί 100. Έτσι για παράδειγμα αν ο αλγόριθμος τα πηγαίνει πολύ καλά για τρεις ταινίες και στη συνέχεια το σκορ βελτιώνεται ελάχιστα τότε αυτός ενδείκνυται για ένα σύστημα συστάσεων για νέους χρήστες όπου δεδομένου λίγων ταινιών ο αλγόριθμος είναι σε θέση να το να προτείνει καλές συστάσεις. Ενώ αν η καλύτερη απόδοση του αλγορίθμου σας είναι βέλτιστη με περισσότερες ταινίες π.χ. 50 τότε αυτός ο αλγόριθμος συστάσεων ενδείκνυται για παλιούς χρήστες με πολλές αξιολόγησεις.

# %% [markdown]
# ---
# ## Κατασκευή Περιβάλλοντος Εργασίας
# ---
# ### Διάβασμα Αρχείων στο Colab (Μόνο για το Colab)
# Αν η υλοποίηση γίνει στο google colab τότε μπορεί να χρησιμοποιηθεί το google drive ως file system. Για να γίνει Mount το google drive τρέχουμε τον παρακάτω κώδικα και κλικάρουμε στο link που θα μας εμφανιστεί.
#
# ```
# from google.colab import drive
# drive.mount('/content/drive')
# import os
# os.listdir('/gdrive/My Drive')
# ```
# Έπειτα στην σελίδα που άνοιξε επιλέγουμε το mail μας και στο επόμενο παράθυρο που θα μας ανοίξει πατάμε Να επιτρέπεται. Στην συνέχεια αντιγράφουμε τον κωδικό που θα μας βγάλει και τον κάνουμε paste στο Input που έχει ανοίξει στο colab. Έτσι πλέον αν έχουμε ανεβάσει ένα αρχείο στο google drive μπορούμε να το βρούμε στην θέση:
#
# ```
# movies_filename = '/gdrive/My Drive/' + movies_metadata.csv
# ```
# Μπορούμε πλέον κανονικά να δουλέψουμε φτιάχνοντας φακέλους ή αρχεία και γενικότερα κάνοντας οτιδήποτε θα κάναμε αν ήμασταν τοπικά.
#
# ### Prolog μέσω Python
#
# Το πακέτο που θα χρησιμοποιηθεί για την επικοινωνία Python και Prolog είναι το pyswip (https://pypi.org/project/pyswip/). Για να δουλέψει το Pyswip  χρειάζεται να υπάρχει το Swi-Prolog το όποιο αν δουλεύουμε τοπικά πρέπει να το εγκαταστήσουμε, ακολουθώντας αντίστοιχες οδηγίες στην σελίδα του εργαλείου. Για να γίνει του Swi-Prolog η εγκατάσταση στο Google Colab πρέπει να τρέξουμε τον παρακάτω κώδικα:
#
# ```
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog/stable
# !sudo apt-get update
# !sudo apt-get install swi-prolog
# ```
# Σε κάποιο σημείο της εκτέλεσης εμφανίζεται ένα μήνυμα ότι πρέπει να πατήσουμε enter σε ένα input για να συνεχίσει η διαδικασία. Έπειτα από αυτό η εκτέλεση θα συνεχίσει χωρίς κάποιο πρόβλημα.
#
# Τέλος πρέπει να εγκαταστήσουμε το pyswip (**όπου και να δουλεύουμε**) όπως παρακάτω:
#
# ```
# !pip isntall pyswip
# ```

# %% [markdown]
# ---
# #Κώδικας για κατασκευή περιβάλλοντος εργασίας
#
# ##Μόνο για Google Colab
#
# Κώδικας για να γίνει Mount to Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')

import os
path="/content/drive/MyDrive/AI2" # με ευκόλο τρόπο μπορείτε να αλλάξετε το path που είναι αποθηκευμένα τα αρχεία σας
# Out:
# Mounted at /content/drive

# %%
# %%capture
#install swi-prolog
# !sudo apt-get install software-properties-common
# !sudo apt-add-repository ppa:swi-prolog
# !sudo apt-get update
# !sudo apt-get install swi-prolog
#install pyswip
# !pip install pyswip

# %% [markdown]
# # **Μέρος 1: Μελέτη των Metadata, Δημιουργία κόσμου και των βασικών queries.**

# %% [markdown]
# 1Α)

# %%
import pandas as pd
from pyswip import Prolog

# %%
# Η βιβλιοθήκη pandas είναι χρήσιμη για την εργασία με τέτοια δεδομένα
import pandas as pd 
path = '/content/drive/MyDrive/AI2/'
# Διάβασμα του αρχείου 'movie_metadata.csv' 
data = pd.read_csv(path + "movies_metadata.csv") 
#Στο csv υπαρχούν κελία με nan τιμές
#Στις θέσεις αυτές βάζουμε 'UNK' πράγμα που  κάνουμε με την παρακάτω συνάρτηση
data.fillna("UNK", inplace=True)
# Preview the first 5 lines of the loaded data 
data.head()
# Out:
#    Unnamed: 0     budget                                    genres  \
# 0           0  237000000  Action|Adventure|Fantasy|Science Fiction
# 1           1  300000000                  Adventure|Fantasy|Action
# 2           2  245000000                    Action|Adventure|Crime
# 3           3  250000000               Action|Crime|Drama|Thriller
# 4           4  260000000          Action|Adventure|Science Fiction
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                        plot_keywords  language  \
# 0  culture clash|future|space war|space colony|so...   English
# 1  ocean|drug abuse|exotic island|east india trad...   English
# 2  spy|based on novel|secret agent|sequel|mi6|bri...  Français
# 3  dc comics|crime fighter|terrorist|secret ident...   English
# 4  based on novel|mars|medallion|space travel|pri...   English
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                             overview  popularity  ...  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577  ...
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615  ...
# 2  A cryptic message from Bond’s past sends him o...  107.376788  ...
# 3  Following the death of District Attorney Harve...  112.312950  ...
# 4  John Carter is a war-weary, former military ca...   43.926995  ...
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
# 2                           A Plan No One Escapes
# 3                                 The Legend Ends
# 4            Lost in our world, found in another.
#
#                                 movie_title vote_average  num_voted_users  \
# 0                                    Avatar          7.2            11800
# 1  Pirates of the Caribbean: At World's End          6.9             4500
# 2                                   Spectre          6.3             4466
# 3                     The Dark Knight Rises          7.6             9106
# 4                               John Carter          6.1             2124
#
#   title_year                   country      director_name     actor_1_name  \
# 0     2009.0  United States of America      James Cameron      Zoe Saldana
# 1     2007.0  United States of America     Gore Verbinski    Orlando Bloom
# 2     2015.0            United Kingdom         Sam Mendes  Christoph Waltz
# 3     2012.0  United States of America  Christopher Nolan    Michael Caine
# 4     2012.0  United States of America     Andrew Stanton     Lynn Collins
#
#        actor_2_name       actor_3_name
# 0  Sigourney Weaver       Stephen Lang
# 1   Keira Knightley  Stellan Skarsgård
# 2       Léa Seydoux      Ralph Fiennes
# 3       Gary Oldman      Anne Hathaway
# 4   Samantha Morton       Willem Dafoe
#
# [5 rows x 27 columns]

# %%
def clean_text(text):
  text = text.replace(u'\xa0', u'')
  text = text.replace(u"'", u'')
  text = text.replace('""', '"')
  text = text.replace(';"', '')
  text = text.replace('";', '')
  text = text.replace('&amp"', '&')
  text = text.replace('"', '')
  text = text.lstrip('\n')
  text = text.lstrip('"')
  text = text.rstrip('\n')
  text = text.rstrip(';')
  text = text.rstrip('"')
  return text

# %%
#create World
#Ορίζουμε τον κόσμο μας
prolog = Prolog()

#Για κάθε row του πίνακα φτιάχνουμε τα κατηγορήματα που θέλουμε να αποθηκέυσουμε
#αρχικά σε μια λίστα με το όνομα literals
literals = []
movie_score = {}
for row in data.itertuples(index=True, name='Pandas'):
  movie_title = clean_text(getattr(row, 'movie_title'))
  movie_country = clean_text(getattr(row, 'country'))

  for genre in getattr(row, 'genres').split("|"):
    literals.append("genre('"+ movie_title +"','"+ genre +"')")
  
  for plotKeyword in getattr(row, 'plot_keywords').split("|"):
    plotKeyword = plotKeyword.replace("'", '')
    literals.append(f"plot_keyword('{movie_title}','{plotKeyword}')")

  for productionCompany in list(eval(getattr(row, 'production_companies'))):
    pcname = productionCompany["name"].replace("'", "")
    literals.append(f"production_company('{movie_title}','{pcname}')")

  literals.append(f"language('{movie_title}','{getattr(row, 'language')}')")

  name = clean_text(getattr(row, 'director_name'))
  literals.append(f"director('{movie_title}','{name}')")
    
  name = clean_text(getattr(row, 'actor_1_name'))
  literals.append(f"actor('{movie_title}','{name}')")
    
  name = clean_text(getattr(row, 'actor_2_name'))
  literals.append(f"actor('{movie_title}','{name}')")
    
  name = clean_text(getattr(row, 'actor_3_name'))
  literals.append(f"actor('{movie_title}','{name}')")

  literals.append(f"country('{movie_title}','{getattr(row, 'country')}')")
  
  
  if(getattr(row, 'release_date') != "UNK"):
    year = int(getattr(row, 'title_year'))
    decade = str(year - year % 10)
    literals.append(f"decade('{movie_title}','{decade}')")

#Η Prolog θέλει τα κατηγορήματά της με την σειρά 
literals.sort()

with open("literals.txt", 'w', encoding = "utf-8") as f:
    for l in literals: f.write(l + '\n')

for literal in literals:
  prolog.assertz(literal)
#   print (literal +'.')

#Επίσης μπορούμε να κάνουμε consult ένα έτοιμο αρχείο στον κόσμο όπως παρακάτω
prolog.consult(path + "db.pl")

# %%
## FOR SUBSEQUENT EXECUTIONS
with open("/content/drive/MyDrive/AI2/literals.txt", 'r', encoding = "utf-8") as f:
    for line in f: prolog.assertz(line)

# %%
prolog.consult("/content/drive/MyDrive/AI2/db.pl")

# %% [markdown]
# 1Β)

# %% [markdown]
# Κοινό θέμα

# %%
q = prolog.query("atLeastThreeCommonGenres('Avatar', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# {'The Hunger Games: Catching Fire', 'G.I. Joe: Retaliation', 'A Sound of Thunder', 'Prince of Persia: The Sands of Time', 'The Thief and the Cobbler', 'Daybreakers', 'Dragonball Evolution', 'Pacific Rim', 'The Hobbit: An Unexpected Journey', 'The Host', 'The Mummy Returns', 'Divergent', 'X-Men: First Class', 'Star Trek: Insurrection', 'Shin Godzilla', 'The Black Hole', 'Race to Witch Mountain', 'Puss in Boots', 'The Day After Tomorrow', 'Sheena', 'The Empire Strikes Back', 'Congo', 'The Monkey King 2', 'Armageddon', 'Conan the Barbarian', 'Mighty Joe Young', 'X-Men', 'Spy Kids 3-D: Game Over', 'Jurassic World', 'The 13th Warrior', 'Terminator Genisys', 'Hellboy II: The Golden Army', 'Transformers: Dark of the Moon', 'Serenity', 'Spider-Man 3', 'The Lost World: Jurassic Park', 'The Covenant', 'Blade: Trinity', 'Predator', 'The Hobbit: The Battle of the Five Armies', 'Pokémon: Spell of the Unknown', 'The Lord of the Rings: The Fellowship of the Ring', 'Paycheck', 'The Last Legion', 'Dungeons & Dragons: Wrath of the Dragon God', 'Star Trek Beyond', 'Southland Tales', 'Star Wars', 'My Super Ex-Girlfriend', 'TRON: Legacy', 'Zathura: A Space Adventure', 'Lara Croft Tomb Raider: The Cradle of Life', 'Fantastic 4: Rise of the Silver Surfer', 'Star Trek VI: The Undiscovered Country', 'Transformers: Age of Extinction', 'Teenage Mutant Ninja Turtles III', '2012', 'Krull', 'Firefox', 'Starship Troopers', 'Babylon A.D.', 'The League of Extraordinary Gentlemen', 'Mad Max: Fury Road', 'In the Name of the King: A Dungeon Siege Tale', 'Logans Run', 'Night at the Museum: Battle of the Smithsonian', 'The Brothers Grimm', 'Spider-Man 2', 'The Lovers', 'Tank Girl', 'Reign of Fire', 'The Hunger Games: Mockingjay - Part 2', 'The Warriors Way', 'Dune', 'Jupiter Ascending', 'Resident Evil: Afterlife', 'Dragon Wars: D-War', 'Deep Rising', 'Predators', 'Monkeybone', 'Journey to the Center of the Earth', 'Red Sonja', 'X-Men: The Last Stand', 'The Time Machine', 'The Sorcerers Apprentice', 'Transformers', 'Megaforce', 'The Blood of Heroes', 'Sky Captain and the World of Tomorrow', 'Eragon', 'Avengers: Age of Ultron', 'The Hunger Games', 'The Avengers', 'Captain America: The Winter Soldier', 'Priest', 'Big Trouble in Little China', 'Pirates of the Caribbean: At Worlds End', 'The Mortal Instruments: City of Bones', 'Superman IV: The Quest for Peace', 'Mad Max 2: The Road Warrior', 'Total Recall', 'The Core', 'G.I. Joe: The Rise of Cobra', '47 Ronin', 'Star Trek: Nemesis', 'Highlander: The Final Dimension', 'Men in Black II', 'Spawn', 'Return of the Jedi', 'The Scorpion King', 'Escape from L.A.', 'Night at the Museum', 'The Incredible Hulk', 'The Island', 'The Fifth Element', 'RoboCop 3', 'The Iron Giant', 'Star Wars: Episode I - The Phantom Menace', 'The Abyss', 'Thunderbirds', 'Highlander', 'How to Train Your Dragon 2', 'In the Name of the King III', 'Iron Man', 'The Saint', 'Green Lantern', 'The Amazing Spider-Man 2', 'Mad Max', 'Lara Croft: Tomb Raider', '9', 'Independence Day: Resurgence', 'The Amazing Spider-Man', 'Underworld: Rise of the Lycans', 'Treasure Planet', 'Highlander: Endgame', 'Planet of the Apes', 'Iron Man 2', 'U.F.O.', 'Star Trek II: The Wrath of Khan', 'The Forbidden Kingdom', 'X-Men Origins: Wolverine', 'Star Wars: Clone Wars: Volume 1', 'X-Men: Days of Future Past', 'Beastmaster 2: Through the Portal of Time', 'Jumper', 'Superman III', 'Inception', 'Star Trek V: The Final Frontier', 'X2', 'Moonraker', 'Mortal Kombat: Annihilation', 'Jimmy Neutron: Boy Genius', 'Aliens in the Attic', 'Knowing', 'Guardians of the Galaxy', 'Anacondas: The Hunt for the Blood Orchid', 'Star Trek: First Contact', 'Captain America: The First Avenger', 'Pirates of the Caribbean: On Stranger Tides', 'The Borrowers', 'BloodRayne', 'Mystery Men', 'Star Trek Into Darkness', 'Star Trek', 'Wild Wild West', 'Steel', 'Damnation Alley', 'Bill & Teds Bogus Journey', 'Suicide Squad', 'Star Wars: Episode III - Revenge of the Sith', 'The Shadow', 'Journey to Saturn', 'E.T ...

# %% [markdown]
# Αρκετά κοινό θέμα

# %%
q = prolog.query("atLeastTwoCommonGenres('Avatar', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# {'The Thief and the Cobbler', 'Dragonball Evolution', 'The Hobbit: An Unexpected Journey', 'Waterworld', 'The Spy Who Loved Me', 'Divergent', 'Centurion', 'The Darkest Hour', 'Harry Potter and the Chamber of Secrets', 'Phenomenon', 'Terminator 3: Rise of the Machines', 'Legend of the Guardians: The Owls of GaHoole', 'Northfork', 'The Spirit', 'The Golden Compass', 'The Empire Strikes Back', 'The Monkey King 2', 'Armageddon', 'Mighty Joe Young', 'Reno 911!: Miami', '30 Minutes or Less', 'Rabbit-Proof Fence', 'Species', 'Ladyhawke', 'Jurassic World', 'Twilight', 'Terminator Genisys', 'Transformers: Dark of the Moon', 'District B13', 'Mission: Impossible - Ghost Protocol', 'The Covenant', 'Blade: Trinity', 'You Only Live Twice', 'Predator', 'Mission: Impossible II', 'Blade II', 'Ink', 'Dungeons & Dragons: Wrath of the Dragon God', 'The Expendables 2', 'Star Trek Beyond', 'Arthur and the Invisibles', 'The Toxic Avenger', 'Star Wars', 'My Super Ex-Girlfriend', 'Walking Tall', 'Flight of the Phoenix', 'Virgin Territory', 'Transformers: Age of Extinction', 'The Adventures of Rocky & Bullwinkle', 'Epic Movie', 'Raiders of the Lost Ark', 'Spider-Man', 'Firefox', 'Rambo: First Blood Part II', 'Harry Potter and the Goblet of Fire', 'Diary of the Dead', 'Planet 51', 'The Polar Express', 'The Brothers Grimm', 'In the Name of the King: A Dungeon Siege Tale', 'Logans Run', 'Johnny English', 'Saints and Soldiers', 'First Blood', 'The Lovers', 'Howls Moving Castle', 'Tank Girl', 'The Hunger Games: Mockingjay - Part 2', 'The Chronicles of Narnia: The Voyage of the Dawn Treader', 'Cotton Comes to Harlem', 'Quantum of Solace', 'A Simple Wish', 'Ronin', 'The Book of Life', 'Predators', 'Dogma', 'Lucky Numbers', 'X-Men: The Last Stand', 'Abraham Lincoln: Vampire Hunter', 'Lost in Space', 'Sherlock Holmes: A Game of Shadows', 'The Time Machine', 'Special', 'Super Mario Bros.', 'The Beastmaster', 'Shrek', 'The Other Side of Heaven', 'The Avengers', 'Monsters vs Aliens', 'Captain America: The Winter Soldier', 'The Legend of the Lone Ranger', 'Mars Attacks!', 'Big Trouble in Little China', 'Blackthorn', 'Pirates of the Caribbean: At Worlds End', 'The Legend of Hells Gate: An American Conspiracy', 'Alice in Wonderland', 'Digimon: The Movie', 'eXistenZ', 'Nothing', 'Money Talks', 'Scooby-Doo 2: Monsters Unleashed', 'The Brave Little Toaster', 'Shrek 2', 'Somewhere in Time', 'Men in Black II', 'All About the Benjamins', 'Escape from L.A.', 'Night at the Museum', 'The Island', 'Impostor', 'RoboCop', 'Equilibrium', 'House of Flying Daggers', 'The Fifth Element', 'The Iron Giant', 'Tracker', 'Immortals', 'Capricorn One', 'March or Die', 'Pan', 'Battle: Los Angeles', 'Thunderbirds', 'Muppets from Space', 'Riddick', 'Cliffhanger', 'The Emperors New Groove', 'Meteor', 'Alive', 'Green Lantern', 'Alien Zone', 'Cloverfield', 'Savva. Heart of the Warrior', 'Black Knight', 'Resident Evil: Extinction', 'The Big Hit', 'Independence Day: Resurgence', 'MacGruber', 'Highlander: Endgame', 'Planet of the Apes', 'Dantes Peak', 'Megiddo: The Omega Code 2', 'Shanghai Noon', 'Warlock', 'The Hole', 'Beastmaster 2: Through the Portal of Time', 'Jumper', 'X2', 'Bulletproof Monk', 'Guardians of the Galaxy', 'Beyond the Black Rainbow', 'Alexander', 'The Martian', '2046', 'BloodRayne', 'Indiana Jones and the Temple of Doom', 'Mystery Men', 'The Good, The Bad, The Weird', 'Damnation Alley', 'Batman Returns', 'Fortress', 'Independence Day', 'Titan A.E.', 'Hansel & Gretel: Witch Hunters', 'End of Days', 'Hellboy', 'Silver Medalist', 'How to Train Your Dragon', 'Action Jackson', 'The Lord of the Rings: The Two Towers', 'The Visitors', 'Man of Steel', 'Oblivion', 'The Twilight Saga: Breaking Dawn - Part 2', 'Solaris', 'Mortal Kombat', 'Escape from the Planet of the Apes', 'Godzilla 2000', 'Caravans', 'Tidal Wave', 'Back to the Future Part III', 'Speed 2: Cruise Control', 'The Incredibles', 'Mission: Impossible III', 'Resident Evil', 'Legend of a Rabbit', 'I Am Number Four', 'Hulk', 'Tuck ...

# %% [markdown]
# Σχετικά κοινό θέμα

# %%
q = prolog.query("atLeastOneCommonGenre('Avatar', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# {'The Triplets of Belleville', 'The Thief and the Cobbler', 'Dragonball Evolution', 'Brick Mansions', 'The Hobbit: An Unexpected Journey', 'Waterworld', 'The Equalizer', 'Maze Runner: The Scorch Trials', 'Harry Potter and the Chamber of Secrets', 'Phenomenon', 'Max Payne', 'The Golden Compass', 'Pontypool', '30 Minutes or Less', 'Terminator Genisys', 'Black November', 'Transformers: Dark of the Moon', 'The Covenant', 'Blade: Trinity', 'Beverly Hills Cop III', 'The Green Hornet', 'Subway', 'Into the Woods', 'Malone', 'The Toxic Avenger', 'The Family Man', 'Flight of the Phoenix', 'Virgin Territory', 'Ransom', 'High Heels and Low Lifes', 'Transformers: Age of Extinction', 'Snow White: A Tale of Terror', 'Exit Wounds', 'Firefox', 'Rambo: First Blood Part II', 'Spaceballs', 'The Curious Case of Benjamin Button', 'Saints and Soldiers', 'Logans Run', 'Screwed', 'The Lovers', 'Kung Pow: Enter the Fist', 'Pain & Gain', 'Ronin', 'Predators', 'Love Me Tender', 'Lucky Numbers', 'Antiviral', 'Casper', 'Super Mario Bros.', 'Special', 'Point Blank', 'The Other Side of Heaven', 'Beautiful Creatures', 'Mars Attacks!', 'Alice in Wonderland', 'Meet Joe Black', 'The Legend of Hells Gate: An American Conspiracy', 'The Monuments Men', 'Shrek 2', 'Men in Black II', 'Impostor', 'Jack Brooks: Monster Slayer', 'Down Terrace', 'The Iron Giant', 'Risen', 'The Brothers Bloom', 'Battle: Los Angeles', 'Into the Grizzly Maze', 'The Prophecy', 'Hereafter', 'The Train', 'Meteor', 'Heavenly Creatures', 'Good Kill', 'The Big Hit', 'Independence Day: Resurgence', 'The Assassination of Jesse James by the Coward Robert Ford', 'MacGruber', 'Dantes Peak', '22 Jump Street', 'Fast Five', 'Jumper', 'Bon Cop Bad Cop', '2046', 'The Adventures of Pinocchio', 'Indiana Jones and the Temple of Doom', 'Mystery Men', 'Apollo 18', 'A Passage to India', 'Pootie Tang', 'Batman Returns', 'Beetlejuice', 'The Mexican', 'Hansel & Gretel: Witch Hunters', 'Kiss Kiss Bang Bang', 'Silver Medalist', 'Gun Shy', 'Duplex', 'Godzilla 2000', 'Hit & Run', 'Beverly Hills Cop', 'Kingdom of the Spiders', 'Mission: Impossible III', 'Dark Shadows', 'Swelter', 'Transporter 2', 'Hulk', 'Tuck Everlasting', 'Thor', 'Conan the Destroyer', 'The Golden Child', 'The Blues Brothers', 'Son of the Mask', 'The Sisterhood of the Traveling Pants 2', 'Kickboxer: Vengeance', 'The Crocodile Hunter: Collision Course', 'Herbie Fully Loaded', 'Up', 'Iron Man 3', 'The Bodyguard', 'Once Upon a Time in Mexico', 'Creative Control', 'Spy Kids', 'The Quiet American', 'The Lovely Bones', 'Containment', 'Cutthroat Island', 'The Wiz', 'Down to Earth', 'The Land Before Time', 'The Call of Cthulhu', 'About Time', 'True Lies', 'Homefront', 'The X Files: I Want to Believe', 'The Four Feathers', 'Black Rain', 'Ironclad', 'The Hobbit: The Battle of the Five Armies', 'The Craft', 'The Last Castle', 'Night Watch', 'Red Riding Hood', 'Warriors of Virtue', 'The Hunt for Red October', 'Area 51', 'Batman: The Dark Knight Returns, Part 2', 'Man on Fire', 'The Sweeney', 'The Muse', 'The Beast from 20,000 Fathoms', 'Mr. & Mrs. Smith', 'Looper', 'Pineapple Express', 'Red Dawn', 'Daylight', 'Dune', 'Red Sky', '2001: A Space Odyssey', 'Checkmate', 'Cargo', 'The Signal', 'Monkeybone', 'The 5th Wave', 'Team America: World Police', 'The Purge: Election Year', 'Are We There Yet?', 'Race', 'Night at the Museum: Secret of the Tomb', 'The Dukes of Hazzard', 'I Spy', 'We Were Soldiers', 'Blue Streak', 'Shade', 'Antz', 'Holy Motors', 'The Misfits', 'What Dreams May Come', 'Dawn of the Dead', 'Flash Gordon', 'Nothing to Lose', 'Star Trek IV: The Voyage Home', 'The Curse of the Were-Rabbit', 'Whats the Worst That Could Happen?', 'Green Zone', 'Wyatt Earp', 'Sweet Sweetbacks Baadasssss Song', 'The Forbidden Kingdom', 'Lawrence of Arabia', 'Invasion U.S.A.', 'The Butterfly Effect', 'Fight Valley', 'On the Road', '2 Guns', 'Bedtime Stories', 'Hav Plenty', 'Star Wars: Episode III - Revenge of the Sith', 'E.T. the Extra-Terrestrial', 'Enders Game', 'The Cold Li ...

# %% [markdown]
# Κοινός σκηνοθέτης

# %%
q = prolog.query("sameDirector(K, M)")
s = set()
for sol in q: s.add((sol['K'],sol['M']))
q.close()
print(s)
# Out:
# {('The Hobbit: The Desolation of Smaug', 'The Lord of the Rings: The Return of the King'), ('Charlie and the Chocolate Factory', 'Planet of the Apes'), ('Blade II', 'Hellboy'), ('Do the Right Thing', 'The Original Kings of Comedy'), ('The Original Kings of Comedy', 'Mo Better Blues'), ('Syriana', 'Abandon'), ('Edward Scissorhands', 'Alice in Wonderland'), ('Once Upon a Time in Mexico', 'Spy Kids'), ('Blade', 'The League of Extraordinary Gentlemen'), ('The Kid', 'The Sorcerers Apprentice'), ('Gone in Sixty Seconds', 'Whiteout'), ('Into the Blue', 'Crazy/Beautiful'), ('Intolerable Cruelty', 'The Hudsucker Proxy'), ('The Twilight Saga: Eclipse', '30 Days of Night'), ('Date Movie', 'Disaster Movie'), ('Indiana Jones and the Temple of Doom', 'Lincoln'), ('Red Riding Hood', 'Twilight'), ('Closer', 'Primary Colors'), ('Straight Outta Compton', 'The Negotiator'), ('Rise of the Entrepreneur: The Search for a Better Way', 'Amidst the Devils Wings'), ('Get on the Bus', 'The Original Kings of Comedy'), ('The Shawshank Redemption', 'The Mist'), ('Diary of the Dead', 'Survival of the Dead'), ('Scrooged', 'Ladyhawke'), ('Death Becomes Her', 'The Walk'), ('Super 8', 'Mission: Impossible III'), ('Neighbors', 'The Five-Year Engagement'), ('Philomena', 'The Queen'), ('Snake Eyes', 'Scarface'), ('Snake Eyes', 'The Untouchables'), ('The Lost World: Jurassic Park', 'Catch Me If You Can'), ('The BFG', 'Catch Me If You Can'), ('Trees Lounge', 'Lonesome Jim'), ('The Big Lebowski', 'The Ladykillers'), ('Scott Pilgrim vs. the World', 'Shaun of the Dead'), ('The Lost World: Jurassic Park', 'The BFG'), ('Changeling', 'Firefox'), ('Lady in the Water', 'The Last Airbender'), ('Mulholland Drive', 'Dune'), ('Broken Arrow', 'Windtalkers'), ('Videodrome', 'Spider'), ('A Lonely Place to Die', 'Plastic'), ('We Were Soldiers', 'Heaven is for Real'), ('Rise of the Entrepreneur: The Search for a Better Way', 'Short Cut to Nirvana: Kumbh Mela'), ('Edward Scissorhands', 'Dark Shadows'), ('Flicka', 'A Home at the End of the World'), ('Phone Booth', 'The Lost Boys'), ('Virgin Territory', 'The Land Girls'), ('5 Days of War', 'The Covenant'), ('Fun with Dick and Jane', 'RED 2'), ('Terminator Salvation', 'Charlies Angels'), ('Disclosure', 'An Everlasting Piece'), ('Jurassic Park', 'Lincoln'), ('Auto Focus', 'Adam Resurrected'), ('The Conversation', 'The Outsiders'), ('Saving Silverman', 'The Benchwarmers'), ('Here Comes the Boom', 'Around the World in 80 Days'), ('The Cotton Club', 'The Rainmaker'), ('Unforgiven', 'Changeling'), ('New York Stories', 'The Godfather: Part II'), ('Joe', 'Our Brand Is Crisis'), ('Network', '12 Angry Men'), ('Swept Away', 'Snatch'), ('Vampires Suck', 'Date Movie'), ('The Perfect Storm', 'Outbreak'), ('Deep Blue Sea', 'Die Hard 2'), ('Boynton Beach Club', 'Fabled'), ('Paa', 'Sex With Strangers'), ('Yes Man', 'Ant-Man'), ('Teeth and Blood', 'Hum To Mohabbat Karega'), ('Hollow Man', 'Total Recall'), ('Beetlejuice', 'Batman Returns'), ('Forrest Gump', 'Beowulf'), ('Mrs Henderson Presents', 'My Beautiful Laundrette'), ('My Beautiful Laundrette', 'High Fidelity'), ('Now You See Me 2', 'Step Up 2: The Streets'), ('The Untouchables', 'Mission to Mars'), ('The Beaver', 'Money Monster'), ('Random Hearts', 'The Firm'), ('Black Hawk Down', 'Exodus: Gods and Kings'), ('Dream with the Fishes', 'Karachi se Lahore'), ('Eraser', 'The Scorpion King'), ('Resident Evil: Retribution', 'Event Horizon'), ('Jack and Jill', 'The Benchwarmers'), ('Blazing Saddles', 'High Anxiety'), ('Killer Joe', 'The Hunted'), ('Side Effects', 'Haywire'), ('50 First Dates', 'The Naked Gun 33⅓: The Final Insult'), ('Maos Last Dancer', 'Mr. Church'), ('Alien³', 'The Game'), ('Running Forever', 'Sharkskin'), ('Reservoir Dogs', 'Pulp Fiction'), ('We Need to Talk About Kevin', 'Morvern Callar'), ('Requiem for a Dream', 'Noah'), ('The Kid', 'Phenomenon'), ('Date Night', 'Big Fat Liar'), ('Jackass 3D', 'Jackass: The Movie'), ('Sharkskin', 'Teeth and Blood'), ('The Informant!', 'Oceans Eleven' ...

# %% [markdown]
# Ακριβώς ίδια πλοκή

# %%
q = prolog.query("atLeastFourCommonKeywords('Avatar', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Star Trek Into Darkness'}

# %% [markdown]
# Σχετικά ίδια πλοκή

# %%
q = prolog.query("atLeastTwoCommonKeywords('Avatar', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Battle: Los Angeles', 'Jason X', 'Planet 51', 'Green Lantern', 'Renaissance', 'Aliens', 'Mission to Mars', 'Jupiter Ascending', 'Treasure Planet', 'Lockout', 'Cypher', 'Interstellar', 'Silent Running', 'Predators', 'Planet of the Apes', 'Cargo', 'Edge of Tomorrow', 'Platoon', 'We Were Soldiers', 'Jimmy Neutron: Boy Genius', 'Alien', 'Terminator Genisys', 'Chicken Little', 'The Thin Red Line', 'Captain America: The Winter Soldier', 'Moon', 'The Hitchhikers Guide to the Galaxy', 'Pirates of the Caribbean: On Stranger Tides', 'The Four Feathers', 'You Only Live Twice', 'Predator', 'Meet Dave', 'A Monster in Paris', 'Star Trek Into Darkness', 'Home', 'Pocahontas', 'The Astronauts Wife', 'Independence Day', 'Enders Game', 'Stargate: The Ark of Truth', 'Titan A.E.', 'I, Robot', 'Repo Man', 'Galaxina', 'Alien³', 'The Fifth Element', 'John Carter', 'The Time Travelers Wife'}

# %% [markdown]
# Ίδιους βασικούς ηθοποιούς

# %%
q = prolog.query("allThreeCommonActors('Avatar', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# set()

# %% [markdown]
# Αρκετά ίδιους βασικούς ηθοποιούς

# %%
q = prolog.query("atLeastTwoCommonActors('Avatar', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# set()

# %% [markdown]
# Σχετικά ίδιους ηθοποιούς

# %%
q = prolog.query("atLeastOneCommonActor('Avatar', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Baby Mama', 'You Again', 'The Words', 'Vantage Point', 'The Book of Life', 'Vamps', 'Drumline', 'Guess Who', 'The Ice Storm', 'Alien', 'Cedar Rapids', 'Guardians of the Galaxy', 'The Losers', 'Star Trek Into Darkness', 'Center Stage', 'The Cold Light of Day', 'Crossroads', 'Galaxy Quest', 'Out of the Furnace', 'Shadow Conspiracy'}

# %% [markdown]
# Ίδια γλώσσα

# %%
q = prolog.query("sameLanguage('Avatar', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Girl with a Pearl Earring', 'The Replacements', 'The Thief and the Cobbler', 'The Switch', 'Dragonball Evolution', 'Brick Mansions', 'The Hobbit: An Unexpected Journey', 'Waterworld', 'The Equalizer', 'Maze Runner: The Scorch Trials', 'The Lords of Salem', 'Harry Potter and the Chamber of Secrets', 'Inside Out', 'Phenomenon', 'Max Payne', 'One Day', 'Hoffa', 'Raising Helen', 'Hard Candy', 'Bride of Chucky', '30 Minutes or Less', 'Blood Work', 'Madeas Witness Protection', 'Salvador', 'Terminator Genisys', 'Transformers: Dark of the Moon', 'The Dictator', 'What a Girl Wants', 'Cecil B. Demented', 'Sweet November', 'About Last Night', 'Room', 'The Covenant', 'Beverly Hills Cop III', 'Kundun', 'Days of Heaven', 'The Green Hornet', 'Never Again', 'Crash', 'Into the Woods', 'Running with Scissors', 'Malone', 'The Family Man', 'A Beautiful Mind', 'The Secret Life of Pets', 'The Toxic Avenger', 'Rugrats Go Wild', 'Flight of the Phoenix', 'Maos Last Dancer', 'Trippin', 'Ransom', 'Virgin Territory', 'High Heels and Low Lifes', 'The Stepfather', 'Wrong Turn', 'Better Luck Tomorrow', 'Transformers: Age of Extinction', 'Friday', 'Courageous', 'Gods Not Dead 2', 'Snow White: A Tale of Terror', 'Kissing Jessica Stein', 'Wicker Park', 'Rambo: First Blood Part II', 'Spaceballs', 'The Curious Case of Benjamin Button', 'The Perfect Storm', 'Saints and Soldiers', 'Logans Run', 'Screwed', 'The Last Station', 'The Lovers', 'A Guy Named Joe', 'Kung Pow: Enter the Fist', 'The Dog Lover', 'The Squid and the Whale', 'Pain & Gain', 'Imagine That', 'Man on the Moon', 'Ronin', 'Magic Mike', 'Predators', 'Love Me Tender', 'Lucky Numbers', 'Antiviral', 'Fun with Dick and Jane', 'Anne of Green Gables', 'Away We Go', 'Extreme Measures', 'Fantasia', 'Miracle', 'Casper', 'Special', 'Super Mario Bros.', 'Point Blank', 'The Other Side of Heaven', 'Beautiful Creatures', 'The Rocker', 'Due Date', 'Cheri', 'Little Children', 'Mars Attacks!', 'Wanderlust', 'Alice in Wonderland', 'Escape from Alcatraz', 'Meet Joe Black', 'Shutter Island', 'Far from Heaven', 'Mumford', 'Rosemarys Baby', 'Slow West', 'The Guru', 'The Legend of Hells Gate: An American Conspiracy', 'The Monuments Men', 'Peeples', 'Shrek 2', 'The Big Tease', 'Men in Black II', 'The Wedding Planner', 'Scary Movie 5', 'Easy Virtue', 'Mother and Child', 'Scary Movie 3', 'Lincoln', 'Impostor', 'A Few Good Men', 'Jack Brooks: Monster Slayer', 'Florence Foster Jenkins', 'Deceptive Practice: The Mysteries and Mentors of Ricky Jay', 'Down Terrace', 'The Iron Giant', 'Risen', 'Snitch', 'American Beauty', 'Spring Breakers', 'The Brothers Bloom', 'My Name Is Khan', 'Whos Your Caddy?', 'Maria Full of Grace', 'As Good as It Gets', 'Battle: Los Angeles', 'Into the Grizzly Maze', 'The Prophecy', 'Hereafter', 'The Young Victoria', 'Heavenly Creatures', 'Meteor', 'Halloween: The Curse of Michael Myers', 'The Curse of Downers Grove', 'The 40 Year Old Virgin', 'The Straight Story', 'Thirteen Conversations About One Thing', 'Walk the Line', 'Good Kill', 'Without Men', 'A Better Life', 'The Big Hit', 'Independence Day: Resurgence', 'Body Double', 'Samsara', 'The Assassination of Jesse James by the Coward Robert Ford', 'MacGruber', 'The Diary of a Teenage Girl', 'Diary of a Wimpy Kid: Dog Days', 'The Hills Have Eyes 2', 'Dantes Peak', 'Radio Days', 'A Single Man', '22 Jump Street', 'Fast Five', 'Wal-Mart: The High Cost of Low Price', 'Janky Promoters', 'Bon Cop Bad Cop', 'Elmer Gantry', 'Battle of the Year', 'Delivery Man', 'Keeping Up with the Steins', 'Dolphin Tale', 'Step Brothers', 'Daddys Home', 'How Green Was My Valley', 'The Best Man Holiday', 'The Lucky Ones', 'Things We Lost in the Fire', 'Winnie the Pooh', 'The Adventures of Pinocchio', 'Indiana Jones and the Temple of Doom', 'Mystery Men', 'Eyes Wide Shut', 'High School Musical', 'Sex and the City 2', 'A Passage to India', 'Pootie Tang', 'Batman Returns', 'Beetlejuice', 'Charlie Bartlett', 'The Mexican', 'Harvard Man', 'Hansel & Gretel: Witch Hunters', 'Kiss Kiss B ...

# %% [markdown]
# Έγχρωμες ή ασπρόμαυρες

# %%
q = prolog.query("blackAndWhite(M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# set()

# %% [markdown]
# Κοινό studio παραγωγής

# %%
q = prolog.query("oneCommonCompany('Avatar', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Romeo + Juliet', 'Wall Street', 'The Big Year', 'Dragonball Evolution', 'Cheaper by the Dozen', 'The Object of My Affection', 'The Heat', 'Idiocracy', 'The Sitter', 'Marmaduke', 'X-Men: First Class', 'Ramona and Beezus', 'State Fair', 'Home Alone 2: Lost in New York', 'Monte Carlo', 'The French Connection', 'Percy Jackson: Sea of Monsters', 'Australia', 'What Lies Beneath', 'Young Frankenstein', 'The Siege', 'Max Payne', 'The Day After Tomorrow', 'Grandmas Boy', 'The Golden Compass', 'From Hell', 'Hoffa', 'Say It Isnt So', 'Reno 911!: Miami', 'Ladyhawke', 'True Lies', 'The Empire Strikes Back', 'The Full Monty', 'X-Men', 'Wall Street: Money Never Sleeps', 'Live Free or Die Hard', 'Water for Elephants', 'Deadline - U.S.A.', 'Garfield: A Tail of Two Kitties', 'Hannibal Rising', 'Kung Fu Panda 3', 'Minority Report', 'The X Files: I Want to Believe', 'Predator', 'The Conjuring 2', 'Alexanders Ragtime Band', 'Scoop', 'Cast Away', 'We Bought a Zoo', 'The Last Legion', 'Die Hard 2', 'Our Family Wedding', 'Butch Cassidy and the Sundance Kid', 'Vera Drake', 'Garfield', 'High Anxiety', 'Moulin Rouge!', 'The Omen', 'The Egyptian', 'The Passion of the Christ', 'Mrs. Doubtfire', 'The Hills Have Eyes', 'Just Married', 'Star Wars', 'The Sound of Music', 'Virgin Territory', 'Flight of the Phoenix', 'Death Sentence', 'Fantastic 4: Rise of the Silver Surfer', 'Titanic', 'That Thing You Do!', 'High Crimes', 'Hairspray', 'Epic Movie', 'The Happening', 'Young Guns', 'Big', 'The League of Extraordinary Gentlemen', 'Knight and Day', 'The Chronicles of Narnia: The Voyage of the Dawn Treader', 'Night at the Museum: Battle of the Smithsonian', 'Like Mike', 'Victor Frankenstein', 'Kung Pow: Enter the Fist', 'The Verdict', 'I Love You, Beth Cooper', 'Jupiter Ascending', 'Fat Albert', 'The Book of Life', 'The Hustler', 'The Other Woman', 'The Rose', 'Predators', 'Love Me Tender', 'Whip It', 'Straightheads', 'X-Men: The Last Stand', 'Abraham Lincoln: Vampire Hunter', 'Cheaper by the Dozen 2', 'Monkeybone', 'Speed', 'Julia', 'Night at the Museum: Secret of the Tomb', 'Eragon', 'Percy Jackson & the Olympians: The Lightning Thief', 'Fantastic Mr. Fox', 'Glee: The Concert Movie', 'Elektra', 'All About Steve', 'This Means War', 'Cleopatra', 'Big Trouble in Little China', 'The Day the Earth Stood Still', 'The Legend of Bagger Vance', 'Brick Lane', 'Ever After: A Cinderella Story', 'Ice Age', 'A Good Day to Die Hard', 'Gentlemans Agreement', 'Notes on a Scandal', 'The Longest Day', 'Die Hard', 'The Descendants', 'Gullivers Travels', 'Patton', 'The Secret Life of Walter Mitty', 'Return of the Jedi', 'Theres Something About Mary', 'Chronicle', 'Deadpool', 'Ravenous', 'Volcano', 'Flyboys', 'Night at the Museum', 'I, Robot', 'The Maze Runner', 'Lincoln', 'Prometheus', 'Brokedown Palace', 'Jingle All the Way', 'The X Files', 'Jennifers Body', 'Road to Perdition', 'The Abyss', 'Home Alone', 'Hide and Seek', 'Taken 2', 'Taken 3', 'Machete', 'Aliens', 'Black Swan', 'Black Knight', 'The Blue Bird', 'Date Night', 'Independence Day: Resurgence', 'X-Men: Apocalypse', 'The Hills Have Eyes 2', 'DodgeBall: A True Underdog Story', 'Broken Arrow', 'Planet of the Apes', 'X-Men Origins: Wolverine', 'Welcome to Mooseport', 'Shallow Hal', 'Hope Floats', 'Office Space', 'What Happens in Vegas', 'X-Men: Days of Future Past', 'Jumper', '20 Dates', 'Just Wright', 'The Watch', 'Diary of a Wimpy Kid', 'Stardust', 'Borat: Cultural Learnings of America for Make Benefit Glorious Nation of Kazakhstan', 'Glitter', 'Taken', 'Aliens in the Attic', 'Flicka', 'Alien', 'X2', 'Love & Other Drugs', 'How Green Was My Valley', 'Swimfan', 'Battle for the Planet of the Apes', 'The Martian', 'Life of Pi', 'The Sentinel', 'Master and Commander: The Far Side of the World', 'Predator 2', 'Beneath the Planet of the Apes', 'Die Hard: With a Vengeance', 'Bride Wars', 'Doctor Dolittle', 'Damnation Alley', 'Babys Day Out', 'Suicide Squad', 'The Robe', 'Kiss of Death', 'The Internship', 'Kingdom of Heaven', 'Inde ...

# %% [markdown]
# Κοινή χώρα παραγωγής

# %%
q = prolog.query("commonCountry('Avatar', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# {'The Replacements', 'The Switch', 'Dragonball Evolution', 'Waterworld', 'The Equalizer', 'Maze Runner: The Scorch Trials', 'Inside Out', 'Phenomenon', 'Max Payne', 'Hoffa', 'Raising Helen', 'Hard Candy', 'Bad Moms', '30 Minutes or Less', 'Blood Work', 'Madeas Witness Protection', 'Terminator Genisys', 'Black November', 'Transformers: Dark of the Moon', 'The Dictator', 'What a Girl Wants', 'Sweet November', 'About Last Night', 'The Covenant', 'Blade: Trinity', 'Beverly Hills Cop III', 'Kundun', 'Days of Heaven', 'The Green Hornet', 'Into the Woods', 'Running with Scissors', 'Malone', 'The Family Man', 'A Beautiful Mind', 'The Secret Life of Pets', 'The Toxic Avenger', 'Rugrats Go Wild', 'Flight of the Phoenix', 'Trippin', 'Ransom', 'The Stepfather', 'Better Luck Tomorrow', 'Transformers: Age of Extinction', 'Friday', 'Courageous', 'Gods Not Dead 2', 'Snow White: A Tale of Terror', 'Kissing Jessica Stein', 'Wicker Park', 'Firefox', 'Rambo: First Blood Part II', 'Spaceballs', 'The Curious Case of Benjamin Button', 'The Perfect Storm', 'Saints and Soldiers', 'Logans Run', 'A Guy Named Joe', 'The Dog Lover', 'The Squid and the Whale', 'Pain & Gain', 'Shalako', 'Imagine That', 'Man on the Moon', 'Magic Mike', 'Predators', 'Love Me Tender', 'Anne of Green Gables', 'Fun with Dick and Jane', 'Away We Go', 'Extreme Measures', 'Fantasia', 'Miracle', 'Casper', 'Special', 'Point Blank', 'The Other Side of Heaven', 'Beautiful Creatures', 'The Rocker', 'Due Date', 'Little Children', 'Mars Attacks!', 'Wanderlust', 'Alice in Wonderland', 'Escape from Alcatraz', 'Meet Joe Black', 'Shutter Island', 'Far from Heaven', 'Mumford', 'Home on the Range', 'Rosemarys Baby', 'The Legend of Hells Gate: An American Conspiracy', 'Peeples', 'Shrek 2', 'The Wedding Planner', 'Men in Black II', 'Scary Movie 5', 'Scary Movie 3', 'Impostor', 'A Few Good Men', 'Deceptive Practice: The Mysteries and Mentors of Ricky Jay', 'The Iron Giant', 'Risen', 'Snitch', 'American Beauty', 'The Brothers Bloom', 'Whos Your Caddy?', 'As Good as It Gets', 'Battle: Los Angeles', 'The Prophecy', 'Hereafter', 'Meteor', 'The Straight Story', 'Halloween: The Curse of Michael Myers', 'The Curse of Downers Grove', 'The 40 Year Old Virgin', 'Thirteen Conversations About One Thing', 'Vicky Cristina Barcelona', 'Good Kill', 'Without Men', 'A Better Life', 'The Big Hit', 'Independence Day: Resurgence', 'Body Double', 'Samsara', 'The Diary of a Teenage Girl', 'MacGruber', 'The Hills Have Eyes 2', 'Diary of a Wimpy Kid: Dog Days', 'Dantes Peak', 'Radio Days', 'A Single Man', '22 Jump Street', 'Fast Five', 'Wal-Mart: The High Cost of Low Price', 'Janky Promoters', 'Mean Girls', 'Elmer Gantry', 'Battle of the Year', 'Delivery Man', 'Keeping Up with the Steins', 'Dolphin Tale', 'Step Brothers', 'Daddys Home', 'How Green Was My Valley', 'The Best Man Holiday', 'The Lucky Ones', 'Things We Lost in the Fire', 'Winnie the Pooh', 'Indiana Jones and the Temple of Doom', 'Mystery Men', 'Sex and the City 2', 'High School Musical', 'Pootie Tang', 'The Big Parade', 'Beetlejuice', 'Charlie Bartlett', 'Harvard Man', 'Religulous', 'Hansel & Gretel: Witch Hunters', 'Kiss Kiss Bang Bang', 'The Bad Lieutenant: Port of Call - New Orleans', 'Me, Myself & Irene', 'Welcome to the Dollhouse', 'Friends with Money', 'Boogie Nights', 'Gun Shy', 'My Fair Lady', 'Coyote Ugly', 'Trading Places', 'Little Black Book', 'The End of the Affair', 'Hit & Run', 'Beverly Hills Cop', 'Kingdom of the Spiders', 'Pride and Glory', 'Sydney White', 'Thats My Boy', 'Whipped', 'Jackie Brown', 'Impact Point', 'Swelter', 'Hulk', 'Tuck Everlasting', 'Thor', 'South Park: Bigger, Longer & Uncut', 'Conan the Destroyer', 'Parental Guidance', 'Seabiscuit', 'The Golden Child', 'Paranormal Activity 4', 'The Blues Brothers', 'The Sisterhood of the Traveling Pants 2', 'Kindergarten Cop', 'Kickboxer: Vengeance', 'Top Five', 'The In Crowd', 'The Way Way Back', 'Willard', 'Herbie Fully Loaded', 'The Night Listener', 'How Stella Got Her Groove Back', 'U ...

# %% [markdown]
# Ίδια δεκαετία

# %%
q = prolog.query("sameDecade('Avatar', M)")
s = set()
for sol in q: s.add(sol['M'])
q.close()
print(s)
# Out:
# {'Girl with a Pearl Earring', 'The Replacements', 'The Triplets of Belleville', 'Dragonball Evolution', 'Harry Potter and the Chamber of Secrets', 'Max Payne', 'The Golden Compass', 'Raising Helen', 'Hard Candy', 'Pontypool', 'Blood Work', 'What a Girl Wants', 'Cecil B. Demented', 'Sweet November', 'The Diving Bell and the Butterfly', 'The Covenant', 'Blade: Trinity', 'The Spanish Apartment', 'Never Again', 'Crash', 'Running with Scissors', 'The Family Man', 'A Beautiful Mind', 'Rugrats Go Wild', 'Flight of the Phoenix', 'Maos Last Dancer', 'Virgin Territory', 'Wrong Turn', 'High Heels and Low Lifes', 'The Stepfather', 'Better Luck Tomorrow', 'Exit Wounds', 'Kissing Jessica Stein', 'Wicker Park', 'The Curious Case of Benjamin Button', 'The Perfect Storm', 'Saints and Soldiers', 'Screwed', 'The Last Station', 'The Squid and the Whale', 'Kung Pow: Enter the Fist', 'Imagine That', 'The Class', 'Lucky Numbers', 'Fun with Dick and Jane', 'Away We Go', 'Miracle', 'Special', 'The Other Side of Heaven', 'The Rocker', 'Cheri', 'Little Children', 'Far from Heaven', 'Home on the Range', 'The Guru', 'The Importance of Being Earnest', 'Shrek 2', 'The Wedding Planner', 'Men in Black II', 'Easy Virtue', 'Mother and Child', 'Scary Movie 3', 'Impostor', 'Jack Brooks: Monster Slayer', 'Down Terrace', 'Whos Your Caddy?', 'The Brothers Bloom', 'Maria Full of Grace', 'The Young Victoria', 'Gory Gory Hallelujah', 'Thirteen Conversations About One Thing', 'The 40 Year Old Virgin', 'Vicky Cristina Barcelona', 'Walk the Line', 'The Assassination of Jesse James by the Coward Robert Ford', 'The Hills Have Eyes 2', 'A Single Man', 'Wal-Mart: The High Cost of Low Price', 'Jumper', 'Janky Promoters', 'Bon Cop Bad Cop', 'Mean Girls', 'Keeping Up with the Steins', 'Step Brothers', 'The Lucky Ones', 'Things We Lost in the Fire', '2046', 'High School Musical', 'Pootie Tang', 'Charlie Bartlett', 'The Mexican', 'Harvard Man', 'Religulous', 'Kiss Kiss Bang Bang', 'The Bad Lieutenant: Port of Call - New Orleans', 'Lost in Translation', 'Me, Myself & Irene', 'Silver Medalist', 'Friends with Money', 'A Shine of Rainbows', 'Gun Shy', 'Duplex', 'The Barbarian Invasions', 'Coyote Ugly', 'Little Black Book', 'Angels & Demons', 'Under the Same Moon', 'Pride and Glory', 'Whipped', 'Sydney White', 'The Worlds Fastest Indian', 'Men with Brooms', 'Impact Point', 'Mission: Impossible III', 'Dogtooth', 'Transporter 2', 'Basic Instinct 2', 'Mondays in the Sun', 'Hulk', 'Tuck Everlasting', 'Seabiscuit', 'The Sisterhood of the Traveling Pants 2', 'Son of the Mask', 'The Crocodile Hunter: Collision Course', 'The In Crowd', 'Femme Fatale', 'Willard', 'Herbie Fully Loaded', 'The Night Listener', 'Up', 'Once Upon a Time in Mexico', 'Downfall', 'The Midnight Meat Train', 'What Women Want', 'Spy Kids', 'The Quiet American', 'K-19: The Widowmaker', 'The Lovely Bones', 'Reign Over Me', 'Hoot', 'Envy', 'Latter Days', 'Down to Earth', 'Australia', 'You, Me and Dupree', 'Appaloosa', 'Dont Say a Word', 'The Call of Cthulhu', 'Winter Passing', 'Saint Ralph', 'The Dangerous Lives of Altar Boys', 'Traffic', 'The X Files: I Want to Believe', 'The Four Feathers', 'Four Single Fathers', 'To Save A Life', 'The Tooth Fairy', 'Kit Kittredge: An American Girl', 'Scott Walker: 30 Century Man', 'The Last Castle', 'Night Watch', 'Monster-in-Law', 'Moulin Rouge!', 'Roadside Romeo', 'Man on Fire', 'The Reader', 'The Hoax', 'The Benchwarmers', 'Veer-Zaara', 'Mr. & Mrs. Smith', 'Eulogy', 'The Messenger', 'Auto Focus', 'Pineapple Express', 'Moonlight Mile', 'Case 39', 'Cargo', 'Slacker Uprising', 'Monkeybone', 'Team America: World Police', 'Are We There Yet?', 'Forty Shades of Blue', 'Hostel', 'Dragonfly', 'The Dukes of Hazzard', 'I Spy', 'Juwanna Mann', 'Sweet Home Alabama', 'Shade', 'We Were Soldiers', 'The Shaggy Dog', 'Angel Eyes', 'World Trade Center', 'Oliver Twist', 'The Mudge Boy', 'Dawn of the Dead', 'In the Bedroom', 'The Curse of the Were-Rabbit', 'Whats the Worst That Could Happen?', 'EuroTrip', ' ...

# %% [markdown]
# # **2ο Μέρος: Recommendation System με βάση μόνο τα χαρακτηριστικά των ταινιών.**
#
# Στο σημείο αυτό με βάση τους κανόνες που κατασκευάστηκαν στο Μέρος 1 θα κατασκευαστούν κατηγορήματα για την ομοιότητα ταινιών. Παρακάτω δίνεται ένα μικρό παράδειγμα ενός κανόνα και πώς αυτός θα μπορούσε να γραφτεί μέσω του Pyswip. Επίσης όπως αναφέρεται και σε σχόλιο παραπάνω θα μπορεί να γραφτεί και μια βάση δεδομένων με τους κανόνες και να γίνει απευθείας consult.
#
# Στο παρακάτω παράδειγμα το 5 και το 4 εκφράζουν την ομοιότητα των ταινιών π.χ. οι ταινίες που παράγονται μέσω του find_similar_5 είναι πιο όμοιες από αυτές που παράγονται μέσω του find_similar_4.

# %%
def simple_recommender(movie):
    s = set()
    for i in range (1,5):
      q = prolog.query("find_sim_"+ str(i)+ "('" + movie +"',M)")
      for soln in q:
        m = soln['M'] 
        if m not in s:
            s.add(soln['M'])
      q.close()
      answers = s
    return answers

# %%
list(simple_recommender('Avatar'))
# Out:
# ['Krrish',
#  'Dont Be Afraid of the Dark',
#  'The Replacement Killers',
#  'Troll Hunter',
#  'Ultraviolet',
#  'Out of Inferno',
#  'Pirates of the Caribbean: At Worlds End',
#  'Zombie Hunter',
#  'Hugo',
#  'Captain America: Civil War',
#  'Shanghai Surprise',
#  'Lost in Space',
#  'The Walking Deceased',
#  'Meet Dave',
#  '15 Minutes',
#  'Apocalypto',
#  'Twilight',
#  'The Age of Adaline',
#  'Paycheck',
#  'Young Frankenstein',
#  'The Time Travelers Wife',
#  'The Sweeney',
#  'The Tree of Life',
#  'They Live',
#  'Dances with Wolves',
#  'Spy Kids',
#  'Soul Surfer',
#  'Year One',
#  'Tora! Tora! Tora!',
#  'The Spiderwick Chronicles',
#  'Mortal Kombat',
#  'Hulk',
#  'The Brass Teapot',
#  'Mystery Men',
#  'To Die For',
#  'All Hat',
#  'The Blues Brothers',
#  'The Mask of Zorro',
#  'Agora',
#  'Brazil',
#  'X-Men',
#  'The Rock',
#  'Days of Thunder',
#  'Mission: Impossible',
#  'Monsters',
#  'Sin City',
#  'The Thirteenth Floor',
#  'The Mist',
#  'On the Road',
#  'Predators',
#  'Chronicle',
#  'The Princess Bride',
#  'RED',
#  'The Living Daylights',
#  'The Fugitive',
#  'Superman IV: The Quest for Peace',
#  'Tuck Everlasting',
#  'Savva. Heart of the Warrior',
#  'The Invasion',
#  'Doctor Dolittle',
#  'The Warriors Way',
#  'X2',
#  'Sphinx',
#  'The Rage: Carrie 2',
#  'Planet of the Apes',
#  'Bedtime Stories',
#  'Big Miracle',
#  'Fools Gold',
#  'The Green Mile',
#  'Batman: The Dark Knight Returns, Part 2',
#  'Central Intelligence',
#  'Krull',
#  'The Legend of Hells Gate: An American Conspiracy',
#  'The Invention of Lying',
#  'Catch That Kid',
#  'Nanny McPhee',
#  'Heavens Gate',
#  'Sheena',
#  'Tidal Wave',
#  'Star Trek II: The Wrath of Khan',
#  'Blue Streak',
#  'The Specialist',
#  'Skin Trade',
#  'Warrior',
#  'Deep Impact',
#  'Fighting Tommy Riley',
#  'Dragon Nest: Warriors Dawn',
#  'The Quick and the Dead',
#  'Sinbad: Legend of the Seven Seas',
#  'Cop Land',
#  'The Misfits',
#  'The Golden Child',
#  'Legend of the Guardians: The Owls of GaHoole',
#  'The Crazies',
#  'Teenage Mutant Ninja Turtles: Out of the Shadows',
#  'The Wiz',
#  'Eraser',
#  'The Hunted',
#  'Man of Steel',
#  'Metropolis',
#  'Max Keebles Big Move',
#  'Bullets Over Broadway',
#  'Righteous Kill',
#  'Flash Gordon',
#  'H.',
#  'From Dusk Till Dawn',
#  'Charlottes Web',
#  'The Transporter',
#  'Night Watch',
#  'Cotton Comes to Harlem',
#  'Mary Poppins',
#  'Deadpool',
#  'Predator',
#  'Lara Croft Tomb Raider: The Cradle of Life',
#  'Down Terrace',
#  'Into the Blue',
#  'Return to the Blue Lagoon',
#  'Falcon Rising',
#  'Sausage Party',
#  'Bad Company',
#  'Highlander',
#  'Def-Con 4',
#  'The Fast and the Furious: Tokyo Drift',
#  'Primer',
#  'The Transporter Refueled',
#  'Spirit: Stallion of the Cimarron',
#  'Kick-Ass 2',
#  'White Fang',
#  'Menace II Society',
#  'Cutthroat Island',
#  'Jackass 3D',
#  'Green Lantern',
#  'Kung Fu Panda 3',
#  'Bloody Sunday',
#  '2046',
#  'G-Force',
#  'Street Fighter: The Legend of Chun-Li',
#  'Dead Man Down',
#  'Star Trek',
#  'Steel',
#  'Ballistic: Ecks vs. Sever',
#  'Big',
#  'Red Sonja',
#  'Cop Out',
#  'The Hunting Party',
#  'Rapa Nui',
#  'Predator 2',
#  'Unknown',
#  'U-571',
#  'Iron Man 3',
#  'Another Earth',
#  'Rob Roy',
#  'Compadres',
#  'Ghosts of Mars',
#  'Exorcist II: The Heretic',
#  'Star Wars',
#  'From Paris with Love',
#  'Journey to the Center of the Earth',
#  'Getaway',
#  'Space Battleship Yamato',
#  'Megamind',
#  'Subway',
#  'What Planet Are You From?',
#  'Exiled',
#  'Lockout',
#  'Krampus',
#  'Divergent',
#  'Casino Royale',
#  'Eragon',
#  'The Thief and the Cobbler',
#  'Hotel Transylvania',
#  'Rescue Dawn',
#  'Nicholas Nickleby',
#  'The Walk',
#  'A Lonely Place to Die',
#  'Enchanted',
#  'American Ninja 2: The Confrontation',
#  'Romeo Must Die',
#  'The Marine 4: Moving Target',
#  'Point Break',
#  'Its a Mad, Mad, Mad, Mad World',
#  'Terminator 2: Judgment Day',
#  'Texas Rangers',
#  'Mulan',
#  'Wasabi',
#  'Mirrormask',
#  'One for the Money',
#  '2 Fast 2 Furious',
#  'DragonHeart',
#  'Jurassic World',
#  'Action Jackson',
#  'A Low Down Dirty Shame',
#  'Maleficent',
#  'The Pacifier',
#  'True Lies',
#  'Once Upon a Time in Mexico',
#  'The Messenger: The Story of Joan of Arc',
#  'Deterrence',
#  'Saints and Soldiers',
#  'Trash',
#  'Starship Troopers',
#  'The Signal',
#  'Gangsters Paradise: Jerusalema',
#  'Mad Money',
#  'Fantastic 4: Rise of the Silver Surfer',
#  'Duma',
#  '2012',
#  'The Italian Job',
#  'Valiant',
#  'Hook',
#  'Love Me Tender',
#  'Team America: World Police',
#  'The Country Bears',
#  'Live and Let Die',
#  'Damnation Alley',
#  'Maximum Risk',
#  'Pain & Gain',
#  'The Net',
#  'The Box',
#  'The Divide',
#  'El Mariachi',
#  'Rampage',
#  'Extreme Ops',
#  'Sound of My Voice',
#  'A Perfect Getaway',
#  'The Golden Compass',
#  'Paul Blart: Mall Cop 2',
#  'Ghost Town',
#  'Wristcutters: A Love Story',
#  'Nighthawks',
#  'Spirited Away',
#  'Alvin and the Chipmunks: Chipwrecked',
#  'Premium Rush',
#  'Only the Strong',
#  'Bedazzled',
#  'End of Days',
#  'Dawn of the Crescent Moon',
#  'Vanilla Sky',
#  'The Thing',
#  'The Book of Eli',
#  'A Knights Tale',
#  'Six Days Seven Nights',
#  'Eagle Eye',
#  'Thunderbirds',
#  'The Good Dinosaur',
#  'Percy Jackson & the Olympians: The Lightning Thief',
#  'My Stepmother is an Alien',
#  'Dark Shadows',
#  'The Hebrew Hammer',
#  'Non-Stop',
#  'Rio 2',
#  'The Little Prince',
#  'Deep Blue Sea',
#  'Thor: The Dark World',
#  '55 Days at Peking',
#  'In Time',
#  'The Spirit',
#  'Harold & Kumar Escape from Guantanamo Bay',
#  'Khiladi 786',
#  'Wicked Blood',
#  'Transcendence',
#  'Gremlins',
#  'The Muse',
#  'The Lord of the Rings: The Two Towers',
#  'Dawn of the Dead',
#  'Guardians of the Galaxy',
#  'Plastic',
#  'The Ghastly Love of Johnny X',
#  'Left Behind',
#  'Executive Decision',
#  'Anaconda',
#  'Red Dawn',
#  'Evan Almighty',
#  'Harry Brown',
#  'Das Boot',
#  'The Boondock Saints II: All Saints Day',
#  'Zathura: A Space Adventure',
#  'The Blue Butterfly',
#  'Brooklyn Rules',
#  'All Is Lost',
#  'Sorcerer',
#  'Assassins',
#  'Monte Carlo',
#  'Jungle Shuffle',
#  'The Dead Undead',
#  'Hollow Man',
#  'Letters to God',
#  'Commando',
#  'How to Train Your Dragon 2',
#  'Jason X',
#  'Heavenly Creatures',
#  'Last Action Hero',
#  'The Expendables',
#  'The Secret of Kells',
#  'The Three Burials of Melquiades Estrada',
#  'Ready to Rumble',
#  'Supernova',
#  'The Family Man',
#  'Star Wars: Episode II - Attack of the Clones',
#  'Spider-Man',
#  'Riddick',
#  'Night at the Museum: Secret of the Tomb',
#  'Antz',
#  'Mad City',
#  'The Road to El Dorado',
#  'Casper',
#  'Sunshine',
#  'Tower Heist',
#  'White Squall',
#  'Enter the Void',
#  'The Host',
#  '2001: A Space Odyssey',
#  'Taken 3',
#  'Maze Runner: The Scorch Trials',
#  'Rumble in the Bronx',
#  'Hells Angels',
#  'Beverly Hills Cop',
#  'The Darkest Hour',
#  'Hero',
#  'The Patriot',
#  'The One',
#  'Born Of War',
#  'Into the Storm',
#  'The Fifth Element',
#  'The Sentinel',
#  'Nerve',
#  'Point Blank',
#  'Austin Powers: The Spy Who Shagged Me',
#  'Silent Trigger',
#  'Antiviral',
#  'Along Came a Spider',
#  'Chicago Overcoat',
#  'Last Holiday',
#  'Beetlejuice',
#  'Underworld: Awakening',
#  'Dr. Dolittle 2',
#  'Grosse Pointe Blank',
#  'The Stepford Wives',
#  'The Day the Earth Stood Still',
#  'War of the Worlds',
#  'Holy Motors',
#  'Vessel',
#  'Alice in Wonderland',
#  'Find Me Guilty',
#  'Lions for Lambs',
#  'Bloodsport',
#  'Amidst the Devils Wings',
#  'Babylon A.D.',
#  'Keanu',
#  'Escape from the Planet of the Apes',
#  '20,000 Leagues Under the Sea',
#  'Laws of Attraction',
#  'Death Race 2000',
#  'Hancock',
#  'Valley of the Wolves: Iraq',
#  'Virtuosity',
#  'The Chronicles of Narnia: The Voyage of the Dawn Treader',
#  'Harry Potter and the Order of the Phoenix',
#  'The Purge',
#  'Star Trek Into Darkness',
#  'Earth to Echo',
#  'The River Wild',
#  'The Last Dragon',
#  'Wanted',
#  'Are We There Yet?',
#  'Bullet to the Head',
#  'The Last Godfather',
#  'Tycoon',
#  'The Hunger Games: Mockingjay - Part 1',
#  'The Man from U.N.C.L.E.',
#  'Teenage Mutant Ninja Turtles II: The Secret of the Ooze',
#  'The X Files: I Want to Believe',
#  'Goldfinger',
#  'Penitentiary',
#  'A Good Day to Die Hard',
#  'Epic',
#  'Donovans Reef',
#  'Petes Dragon',
#  'Army of Darkness',
#  'Prince of Persia: The Sands of Time',
#  'Spy Hard',
#  'Pan',
#  'The Beastmaster',
#  'The Forbidden Kingdom',
#  'The Pirates! In an Adventure with Scientists!',
#  'War',
#  'Money Talks',
#  'The Dark Knight Rises',
#  'After Earth',
#  'Medicine Man',
#  'Code of Honor',
#  'Wolf',
#  'Aliens',
#  'Kiss Kiss Bang Bang',
#  'Batman & Robin',
#  'Kickboxer: Vengeance',
#  'Gangster Squad',
#  'Ink',
#  'Ironclad',
#  'The Legend of Bagger Vance',
#  'Sherlock Holmes: A Game of Shadows',
#  'Dreamcatcher',
#  'Invaders from Mars',
#  'The Bounty',
#  'Heroes of Dirt',
#  'The Nutty Professor',
#  'Colombiana',
#  'Hot Fuzz',
#  'Rambo: First Blood Part II',
#  'Just Visiting',
#  'The Empire Strikes Back',
#  'Criminal',
#  'Dracula Untold',
#  'Mars Needs Moms',
#  'Escape from L.A.',
#  'Twister',
#  'Alien³',
#  'Pacific Rim',
#  'The Mummy: Tomb of the Dragon Emperor',
#  'The Crew',
#  'Sands of Iwo Jima',
#  'The Life Aquatic with Steve Zissou',
#  'The Matrix',
#  'Vampires',
#  'Everest',
#  'Ice Age',
#  'The Four Feathers',
#  'The Brothers Bloom',
#  'Moonraker',
#  'Northfork',
#  'The 51st State',
#  'I, Robot',
#  'Basic',
#  'Jekyll and Hyde ... Together Again',
#  'Black November',
#  'Furious 7',
#  'Holes',
#  'ParaNorman',
#  'Children of Men',
#  'Galaxina',
#  'Space Pirate Captain Harlock',
#  'Running Scared',
#  'Bolt',
#  'Space Jam',
#  'Open Season',
#  'Lion of the Desert',
#  'Escape from Tomorrow',
#  'Gerry',
#  'Akira',
#  'Wild Wild West',
#  '300',
#  'Hackers',
#  'Transporter 2',
#  'The Tourist',
#  'Why I Did (Not) Eat My Father',
#  'Black Rain',
#  'Hollywood Homicide',
#  'You Only Live Twice',
#  'Quest for Fire',
#  'Rat Race',
#  'Pontypool',
#  'Forbidden Kingdom',
#  'See Spot Run',
#  'Ella Enchanted',
#  'Ice Age: The Meltdown',
#  'The First Great Train Robbery',
#  'The Hunger Games: Mockingjay - Part 2',
#  'The Kid',
#  'Collateral Damage',
#  'Arn: The Knight Templar',
#  'Kate & Leopold',
#  'The Adventures of Pinocchio',
#  'The Hobbit: An Unexpected Journey',
#  'The Hobbit: The Battle of the Five Armies',
#  'Queen of the Damned',
#  'The Man with the Golden Gun',
#  'The Nutcracker',
#  'Midnight Run',
#  'The Toxic Avenger',
#  'Ghostbusters',
#  'Transformers',
#  'Good Boy!',
#  'Shaft',
#  'Astro Boy',
#  'The Lost Medallion: The Adventures of Billy Stone',
#  'Curse of the Golden Flower',
#  'Jupiter Ascending',
#  'Bronson',
#  'Small Soldiers',
#  'The Clan of the Cave Bear',
#  'Soldier',
#  'Star Trek VI: The Undiscovered Country',
#  'Roar',
#  'Kill Bill: Vol. 2',
#  'The BFG',
#  'Cube',
#  'Jason Goes to Hell: The Final Friday',
#  'The League of Extraordinary Gentlemen',
#  'Cast Away',
#  'The Wild Bunch',
#  'The Last Legion',
#  'Flubber',
#  'Doomsday',
#  'What Dreams May Come',
#  '10 Cloverfield Lane',
#  'Blade',
#  'Jimmy and Judy',
#  'Machete Kills',
#  'Rush Hour 2',
#  'Cloverfield',
#  'Creative Control',
#  'Penguins of Madagascar',
#  'Thunder and the House of Magic',
#  'Robin Hood',
#  'Spy Kids 2: The Island of Lost Dreams',
#  'Beverly Hills Cop II',
#  'Double Take',
#  'Harper',
#  'Reign of Assassins',
#  'Without a Paddle',
#  'The World Is Not Enough',
#  'The Warlords',
#  'Heist',
#  'Shinjuku Incident',
#  'Big Mommas: Like Father, Like Son',
#  'The Mask',
#  'Hereafter',
#  'The Amazing Spider-Man',
#  'The Jacket',
#  'Limbo',
#  'Khumba',
#  'Bodyguards and Assassins',
#  'Tango & Cash',
#  'Rockaway',
#  'Monty Python and the Holy Grail',
#  'The Prince of Egypt',
#  'Robots',
#  'Made',
#  'We Were Soldiers',
#  'Frequency',
#  'Alice Through the Looking Glass',
#  'The Sum of All Fears',
#  'Real Steel',
#  'Snow White and the Huntsman',
#  'The Monuments Men',
#  'The Incredible Hulk',
#  'Watchmen',
#  'Con Air',
#  'Hanna',
#  'Highlander: The Final Dimension',
#  'Phantasm II',
#  'Gods of Egypt',
#  'Confidence',
#  'Man on a Ledge',
#  'Sleeper',
#  'In the Name of the King III',
#  'Snowpiercer',
#  'Rush',
#  'Fantastic Four',
#  'Ultramarines: A Warhammer 40,000 Movie',
#  'The Matrix Revolutions',
#  'Babys Day Out',
#  'Crank',
#  'Rambo III',
#  'Highway',
#  'Pokémon: Spell of the Unknown',
#  'Open Road',
#  'Switchback',
#  'The Twilight Saga: Breaking Dawn - Part 2',
#  'New Nightmare',
#  'Multiplicity',
#  'Moon',
#  'Run All Night',
#  'Self/less',
#  'The Abyss',
#  'Skyline',
#  'Hellboy',
#  'The Matador',
#  'Subconscious',
#  'Repo Man',
#  'Kicks',
#  'Superhero Movie',
#  'The Adventures of Rocky & Bullwinkle',
#  'Bad Boys II',
#  'RoboCop 3',
#  'The Nutcracker: The Untold Story',
#  'Priest',
#  'Batman Begins',
#  'Charlies Angels',
#  'Vantage Point',
#  'Quarantine',
#  'Cargo',
#  'Shrek the Third',
#  'Die Another Day',
#  'Bill & Teds Excellent Adventure',
#  'Avengers: Age of Ultron',
#  'Gamer',
#  'Alex Cross',
#  'Resident Evil: Retribution',
#  'Super',
#  'Royal Kill',
#  'Stake Land',
#  'The Muppet Christmas Carol',
#  'Suicide Squad',
#  'The Quiet American',
#  '16 Blocks',
#  'The Assassination of Jesse James by the Coward Robert Ford',
#  'The Triplets of Belleville',
#  'Lethal Weapon 4',
#  'The Wicked Lady',
#  'Tears of the Sun',
#  'The Wolverine',
#  'Shanghai Knights',
#  'Contact',
#  'Escape from New York',
#  'Alien: Resurrection',
#  'Spaced Invaders',
#  'Pixels',
#  'Quantum of Solace',
#  'The Covenant',
#  'Dogma',
#  'The Young and Prodigious T.S. Spivet',
#  'Max',
#  'Tae Guk Gi: The Brotherhood of War',
#  'Austin Powers: International Man of Mystery',
#  'Air Force One',
#  'Men of War',
#  'The Adventures of Huck Finn',
#  'The Bourne Supremacy',
#  'Never Back Down',
#  'The Giver',
#  'Scooby-Doo',
#  'Domino',
#  'The Island',
#  'September Dawn',
#  'Beyond Borders',
#  'The Flintstones in Viva Rock Vegas',
#  'Drive Angry',
#  'Set It Off',
#  'Big Trouble in Little China',
#  'Hud',
#  'Rise of the Planet of the Apes',
#  'I Am Legend',
#  'Silverado',
#  'Son of the Mask',
#  'The Adventures of Pluto Nash',
#  'Bandidas',
#  'Henry V',
#  'Sherlock Holmes',
#  'The Hobbit: The Desolation of Smaug',
#  'Jaws: The Revenge',
#  'Fury',
#  'You Dont Mess with the Zohan',
#  'Fight to the Finish',
#  'Alatriste',
#  'TMNT',
#  'The Call of Cthulhu',
#  'White House Down',
#  'Impostor',
#  'The Lone Ranger',
#  'Iron Man 2',
#  'The Black Hole',
#  'Alien Zone',
#  'Joe Dirt',
#  'The Secret Life of Walter Mitty',
#  'Dick Tracy',
#  'Crouching Tiger, Hidden Dragon',
#  'The Matrix Reloaded',
#  'Dune',
#  'Noah',
#  'For Your Eyes Only',
#  'Under the Skin',
#  'The Illusionist',
#  'The Heat',
#  'Red Sky',
#  'Snow White and the Seven Dwarfs',
#  'Capricorn One',
#  'Re-Kill',
#  'Ninja Assassin',
#  'Delgo',
#  'Max Payne',
#  'Paul Blart: Mall Cop',
#  'Yogi Bear',
#  'Stormbreaker',
#  'Logans Run',
#  'xXx: State of the Union',
#  'Star Wars: Episode III - Revenge of the Sith',
#  'Man of the House',
#  'The Big Hit',
#  'Titan A.E.',
#  'Johnny English Reborn',
#  'Against the Wild',
#  'Half Past Dead',
#  'Grand Theft Parsons',
#  'The Road',
#  'Blood Diamond',
#  '3 Strikes',
#  'The Last Days on Mars',
#  'Showdown in Little Tokyo',
#  'Walking With Dinosaurs',
#  'Jurassic Park III',
#  'Unbreakable',
#  'Thunderball',
#  'I Am Number Four',
#  'The Mighty Macs',
#  'Skyfall',
#  'Resident Evil: Extinction',
#  'The Revenant',
#  'Flyboys',
#  'Stardust',
#  'The Timber',
#  'Shadow Conspiracy',
#  'Checkmate',
#  'Queen Crab',
#  'Love & Basketball',
#  'Duplex',
#  'Lucky Break',
#  'Repo! The Genetic Opera',
#  'Master and Commander: The Far Side of the World',
#  'Killer Elite',
#  'Changing Lanes',
#  'Perrier’s Bounty',
#  'Just My Luck',
#  'Hansel & Gretel: Witch Hunters',
#  'First Blood',
#  'The Cold Light of Day',
#  'Event Horizon',
#  'Bound by Honor',
#  'Star Trek: The Motion Picture',
#  'Howard the Duck',
#  'Super 8',
#  'London',
#  'Kiss of Death',
#  'Behind Enemy Lines',
#  'Small Time Crooks',
#  'R.I.P.D.',
#  'Hit & Run',
#  'Red Riding Hood',
#  'Renaissance',
#  'Superman Returns',
#  'Groundhog Day',
#  'Breakdown',
#  'Red State',
#  'The Blood of Heroes',
#  'Cypher',
#  'CJ7',
#  'Lifeforce',
#  'Seeking a Friend for the End of the World',
#  'Reno 911!: Miami',
#  'Act of Valor',
#  '12 Rounds',
#  'The Long Kiss Goodnight',
#  'The Astronaut Farmer',
#  'Killing Zoe',
#  'Risen',
#  'The Book of Life',
#  'The Ghost and the Darkness',
#  'The True Story of Puss n Boots',
#  'Tomorrow Never Dies',
#  'VeggieTales: The Pirates Who Dont Do Anything',
#  'Taken 2',
#  'Peggy Sue Got Married',
#  'Midnight in Paris',
#  'Mortal Kombat: Annihilation',
#  'The Hunt for Red October',
#  'The Edge',
#  'Lawrence of Arabia',
#  'The Interview',
#  'Fight Valley',
#  'Allegiant',
#  'District 9',
#  'The Lawnmower Man',
#  'Double Impact',
#  'Ice Age: Dawn of the Dinosaurs',
#  'S.W.A.T.',
#  'The I Inside',
#  '47 Ronin',
#  'The Hit List',
#  'U.F.O.',
#  'Princess Mononoke',
#  'In Her Line of Fire',
#  '127 Hours',
#  'Jack Brooks: Monster Slayer',
#  'Monster House',
#  'The Saint',
#  'Repo Men',
#  'Sphere',
#  'Automata',
#  'The Cat in the Hat',
#  'Aliens vs Predator: Requiem',
#  'Around the World in 80 Days',
#  'Looper',
#  'Inkheart',
#  'Curious George',
#  'Land of the Lost',
#  'The Devils Double',
#  'Patriot Games',
#  'C.H.U.D.',
#  'Crocodile Dundee',
#  'Pineapple Express',
#  'Back to the Future',
#  'O Brother, Where Art Thou?',
#  'Pirates of the Caribbean: The Curse of the Black Pearl',
#  'George and the Dragon',
#  'The Jungle Book 2',
#  'Abraham Lincoln: Vampire Hunter',
#  'Gunless',
#  'Underworld: Rise of the Lycans',
#  'Alpha and Omega: The Legend of the Saw Tooth Cave',
#  'Star Trek: Nemesis',
#  'Snakes on a Plane',
#  'The Phantom',
#  'Gone in Sixty Seconds',
#  'Underworld: Evolution',
#  'Shrek Forever After',
#  'Braveheart',
#  'Jurassic Park',
#  'The Mummy Returns',
#  'The Lord of the Rings: The Fellowship of the Ring',
#  'Asterix at the Olympic Games',
#  'Prometheus',
#  'Bogus',
#  '28 Weeks Later',
#  'Being John Malkovich',
#  'Ronin',
#  'A Sound of Thunder',
#  'Barbarella',
#  'Sweet Sweetbacks Baadasssss Song',
#  'The X Files',
#  'The Scorpion King',
#  'X-Men: Apocalypse',
#  'X-Men: Days of Future Past',
#  'The French Connection',
#  'The NeverEnding Story',
#  'The Sisterhood of the Traveling Pants 2',
#  'xXx',
#  'Blades of Glory',
#  'The Maze Runner',
#  'The Island of Dr. Moreau',
#  'Blindness',
#  'First Knight',
#  'The Train',
#  'Antarctica: A Year on Ice',
#  'A Simple Wish',
#  'Shrek',
#  'The Score',
#  'The Smurfs',
#  'Travellers and Magicians',
#  'Chicago',
#  'Aladdin',
#  'Beowulf',
#  'Captain Phillips',
#  'Timecrimes',
#  'Night at the Museum',
#  'Never Let Me Go',
#  'Babe: Pig in the City',
#  'Dragon Wars: D-War',
#  'Road House',
#  'Bee Movie',
#  'Clash of the Titans',
#  'I Got the Hook Up',
#  'DOA: Dead or Alive',
#  'Disturbing Behavior',
#  'Robin and Marian',
#  'The Grey',
#  'Race to Witch Mountain',
#  'Unleashed',
#  'The Dark Hours',
#  'The Promise',
#  'Nowhere to Run',
#  'Warcraft',
#  'Star Trek III: The Search for Spock',
#  'Life of Pi',
#  'Shade',
#  'The Muppet Movie',
#  'Edward Scissorhands',
#  'Sicario',
#  'Warlock: The Armageddon',
#  'Ladder 49',
#  'The Longest Day',
#  'Wild Hogs',
#  'Scrooged',
#  'A Bugs Life',
#  'Cars 2',
#  'The Purge: Election Year',
#  'Brave',
#  'House of Flying Daggers',
#  'Mortdecai',
#  'In the Heart of the Sea',
#  'Galaxy Quest',
#  'The Specials',
#  'Topaz',
#  'Blade Runner',
#  'The Forsaken',
#  'Pirates of the Caribbean: On Stranger Tides',
#  'Death Race',
#  'The Man from Earth',
#  'Speed',
#  'Carriers',
#  'Attack the Block',
#  'The Good, The Bad, The Weird',
#  'Battleship',
#  'Ted',
#  'A.I. Artificial Intelligence',
#  'Silent Running',
#  'Kung Pow: Enter the Fist',
#  'The Faculty',
#  'The Pursuit of D.B. Cooper',
#  'The Boxtrolls',
#  'The Helix... Loaded',
#  'Scott Pilgrim vs. the World',
#  'Muppets from Space',
#  'Creature',
#  'eXistenZ',
#  'E.T. the Extra-Terrestrial',
#  'One Mans Hero',
#  'Sahara',
#  'Legend of a Rabbit',
#  'Tomorrowland',
#  'The Core',
#  'Johnny English',
#  'Street Fighter',
#  'The Legend of the Lone Ranger',
#  'Airborne',
#  'Speed 2: Cruise Control',
#  'Now You See Me 2',
#  'The Spy Who Loved Me',
#  'Killers',
#  'Spy Kids: All the Time in the World',
#  'Gravity',
#  'Exodus: Gods and Kings',
#  'Death Becomes Her',
#  'Batman v Superman: Dawn of Justice',
#  'Lucky Numbers',
#  'Waterworld',
#  'The Wild Thornberrys Movie',
#  'Up',
#  'Southland Tales',
#  'Star Trek: Insurrection',
#  'Hocus Pocus',
#  'Phenomenon',
#  'Bang Bang Baby',
#  'A Scanner Darkly',
#  'Journey 2: The Mysterious Island',
#  'War, Inc.',
#  'Driven',
#  'Rubber',
#  'Deuces Wild',
#  'Immortals',
#  'Enter Nowhere',
#  'Blade II',
#  'Operation Chromite',
#  'How the Grinch Stole Christmas',
#  'Muppets Most Wanted',
#  'The Sticky Fingers of Time',
#  'Dead Like Me: Life After Death',
#  'Rotor DR1',
#  'Mad Max: Fury Road',
#  'Universal Soldier: The Return',
#  'Splice',
#  'The Other Side of Heaven',
#  'The Limey',
#  'Flipper',
#  'Code Name: The Cleaner',
#  'The Jungle Book',
#  'Steamboy',
#  'The Lovers',
#  'Apollo 18',
#  'Elf',
#  'The Proposition',
#  'Interstellar',
#  'Minions',
#  'Flight of the Phoenix',
#  'Paint Your Wagon',
#  'Meteor',
#  'Mission to Mars',
#  'Gremlins 2: The New Batch',
#  'American Heist',
#  'WarGames',
#  'The Glimmer Man',
#  'After the Sunset',
#  'Videodrome',
#  'Olympus Has Fallen',
#  'The Man Who Knew Too Little',
#  'The Descent',
#  'Dragonball Evolution',
#  'Four Brothers',
#  'Cirque du Freak: The Vampires Assistant',
#  'The November Man',
#  'The Peacemaker',
#  'The Black Stallion',
#  'Cradle 2 the Grave',
#  'In the Name of the King: A Dungeon Siege Tale',
#  'Hobo with a Shotgun',
#  'The Emperors New Groove',
#  'On Deadly Ground',
#  'Jack Ryan: Shadow Recruit',
#  'Chappie',
#  'The Jackal',
#  'Mighty Joe Young',
#  ...]

# %% [markdown]
# # **3ο Μέρος: Recommendation System Με βάση τις προτιμήσεις-Αξιολογήσεις του χρήστη-Εκπαίδευση και Πρόβλεψη**
#
#
# Αρχικά μελετάμε τις αξιολογήσεις κάθε χρήστη για να καταλάβουμε την δομή και τις πληροφορίες κάθε αρχείου.

# %%
from tqdm.notebook import tqdm
from sklearn.metrics import precision_score, recall_score, f1_score
import numpy as np
import random

rating_weights = {0: -1, 1: -0.5, 2:0, 3:0, 4:0.5, 5:1}
score_weights = {i:i + 1 for i in range(1)} # ανάλογα με τα επίπεδα ομοιότητας που έχουν οριστεί στην simple_recommender

def train_recommender(ratings, rating_weights, score_weights, number_of_movies = 10):
    """
    Στην συνάρτηση αυτή μπορούμε να ορίζουμε ποιο υποσύνολο των αξιολογήσεων θα χρησιμοποιήσουμε για το train μαζί με τα βάρη ομοιότητας και σκορ
    Σε συνδυασμό με τον αριθμό των ταινιών που θέλουμε να χρησιμοποιήσουμε σαν σύνολο δεδομένων π.χ. 10 από τις 100 ή 3 από τις 100 κ.ο.κ
    Αν θέλουμε να χρησιμοποιήσουμε όλες τις ταινίες σαν training set τότε ορίζουμε το number_of_movies = - 1
    """

    if number_of_movies > len(ratings):
        number_of_movies = len(ratings)


    if number_of_movies != -1:
        indexes = random.sample(range(len(ratings)), number_of_movies)
        ratings = ratings.iloc[indexes]

    movie_score = {}
    for row in tqdm(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        similar_movies = simple_recommender(movie)

        for similar_movie in similar_movies:
            if similar_movie not in movie_score:
                movie_score[similar_movie] = rating_weights[int(rating)] * score_weights[0]
            else:
                movie_score[similar_movie] += rating_weights[int(rating)] * score_weights[0] # το weight θα το ορίσετε ανα επίπεδο ομοιότητας οι πολύ όμοιες ταινίες θα έχουν μεγαλύτερο βάρος
    return movie_score


# Αυτό είναι ένα παράδειγμα για το πως θα μπορούσε να υλοποιήθει η predict.
# Έχουμε ορίσει ότι μια ταινία θα έπρεπε να είναι προτεινόμενη αν είχε σκορ > 0.
def predict_example(ratings, movie_score):
    real, pred = [], []
    for i, row in enumerate(ratings.itertuples(index=True, name='Pandas')):
        movie = clean_text(getattr(row, 'movie_title'))
        rating = getattr(row, 'rating')

        if movie in movie_score: #αν έχουμε σχηματίσει βαθμολογία για την ταινία αυτή
            pred.append(int(movie_score[movie] > 0)) #heuristic για το αν μια ταινία είναι προτεινόμενη
            real.append(int(rating > 3))# έτσι ορίζουμε ότι μια ταινία θα έπρεπε να είναι προτεινόμενη
            #η συνθήκη αυτή δεν μπορεί να αλλάξει
        else: #δεν μπορούμε να προτείνουμε κάτι για το όποιο δεν έχουμε σχηματίσει εικόνα
            pred.append(0)
            real.append(int(rating > 3))

    return real, pred


def get_metrics(real, pred):
    metrics = {}
    metrics["precision"] = precision_score(real, pred)
    metrics["recall"] = recall_score(real, pred)
    metrics["f1"] = f1_score(real, pred)
    return metrics

# %% [markdown]
# Η παραπάνω εκπαιδεύουν, τεστάρουν και μετρούν την απόδοσή του συστήματος στάσεων μας. Για την εκπαίδευση του συστήματος μπορούμε κάθε φορά να χρησιμοποιήσουμε ένα τυχαίο υποσύνολο του training set. Όμως είναι πιθανό το υποσύνολο των ταινιών αυτόν να επηρεάζει τα αποτελέσματα στο training set. Για παράδειγμα από 3 ταινίες στις 10 μπορούν για ένα πείραμα τα αποτελέσματα μας αν είναι ίδια και αυτό να μην οφείλεται στο γεγονός ότι ο ταξινομητής μας τα πηγαίνει καλά στις 3 ταινίες αλλά στο γεγονός ότι οι υπόλοιπες 7 είναι τέτοιες ταινίες που δεν μας βοηθούν καθόλου και αν είχαμε επιλέξει διαφορετικές 3 ταινίες να τα πηγαίναμε χάλια. Οπότε προτείνουμε να τρέξετε κάθε φορά έναν αριθμό πειραμάτων για κάθε υποσύνολο ταινιών π.χ. 10 πειράματα με 3 ταινίες, 10 πειράματα για 20 ταινίες κ.ο.κ. και να κρατήσετε σαν τελικό σκορ το μέσο όρο όλων των πειραμάτων. Έτσι τα αποτελέσματα των αγγλικών σας θα είναι πιο αντικειμενικά.

# %%
train_ratings = pd.read_csv(path + "train_ratings.csv")
test_ratings = pd.read_csv(path + "test_ratings.csv")

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 10)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5206890438346888
# recall: 0.7805555555555557
# f1: 0.5878085569382552

# %%
metrics = []
for i in range (10):
    movie_score = train_recommender(train_ratings, rating_weights, score_weights, 30)
    real, pred = predict_example(test_ratings, movie_score)
    metrics.append(get_metrics(real, pred))

for metric in metrics[0].keys():
    print (f"{metric}: {np.mean([m[metric] for m in metrics])}")
# Out:
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# precision: 0.5083592888569252
# recall: 0.9680555555555556
# f1: 0.666601282435541
